# %% [markdown]
# # Lab 1 · Colab, Python, and Your First Look at Data
# **EE 3040 Introduction to AI** · self-paced · **Lab: about 3 hours** (Parts 1 to 7) · **Homework: Part 8, due one week later**
#
# The director of a city's electricity distribution department asks: *"Can AI warn us six hours before a transformer overloads?"*
# The answer starts with a table of past readings. In this lab you open that table, find what is wrong with it, and compute the number any model must beat.
# You also set up a free AI assistant. In the homework you apply the same first look to **your own data**, clearly and honestly.
#
# **In this lab you**
# 1. Run and edit a Colab notebook without breaking it.
# 2. Write the few lines of Python this course needs: variables, lists, functions, and f-strings.
# 3. Load a table with pandas and describe it: rows, columns, types, missing values, strange values.
# 4. Plot a column over time and against another column, and say what the plot shows.
# 5. Compute a baseline error that every future model must beat.
# 6. Call a free large language model from Python, and check its answer instead of trusting it.
#
# **What you hand in**
# - **The lab (Part 7):** your checks, your findings table, the baseline error, and your verdict on the AI assistant. You sign it with your university email and add a link to your notebook, shared with your instructor.
# - **The homework (Part 8, one week later):** three findings on your own data, and where the data comes from.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **اللاب 1 · Colab وبايثون وأول نظرة على البيانات**
#
# **مقرر ٣٠٤٠ كهر مقدمة في الذكاء الاصطناعي** · بالتعلم الذاتي · **اللاب: نحو 3 ساعات** (الأجزاء 1 إلى 7) · **الواجب: الجزء 8، يُسلَّم بعد أسبوع**
#
# يسأل مدير إدارة توزيع الكهرباء في المدينة: *«هل يستطيع الذكاء الاصطناعي أن ينذرنا قبل ست ساعات من الحمل الزائد على محوّل؟»*
# والإجابة تبدأ بجدول قراءات سابقة. في هذا اللاب تفتح ذلك الجدول، وتكتشف ما فيه من أخطاء، وتحسب الرقم الذي يجب أن يتفوق عليه أي نموذج.
# وتجهّز أيضاً مساعداً ذكياً مجانياً. وفي الواجب تطبّق النظرة الأولى نفسها على **بياناتك**، بدقة ووضوح.
#
# **في هذا اللاب:**
#
# 1. تشغّل دفتر Colab وتعدّله دون أن تفسده.
# 2. تكتب الأسطر القليلة من بايثون التي يحتاجها المقرر: المتغيرات والقوائم والدوال وصيغة f-string.
# 3. تحمّل جدولاً بمكتبة pandas وتصفه: عدد الصفوف والأعمدة، وأنواعها، والقيم المفقودة، والقيم الغريبة.
# 4. ترسم عموداً عبر الزمن وعموداً مقابل آخر، وتقول ماذا يُظهر الرسم.
# 5. تحسب خطأ خط الأساس الذي يجب أن يتفوق عليه كل نموذج لاحق.
# 6. تستدعي نموذج لغة كبيراً مجانياً من بايثون، وتتحقق من إجابته بدل أن تثق بها.
#
# **ما تسلّمه**
#
# - **اللاب (الجزء 7):** نتائج التحقق، وجدول ملاحظاتك، وخطأ خط الأساس، وحكمك على المساعد الذكي. توقّعها ببريدك الجامعي، وتضيف رابط دفترك بعد مشاركته مع أستاذك.
# - **الواجب (الجزء 8، بعد أسبوع):** ثلاث ملاحظات على بياناتك، ومصدر هذه البيانات.
#
# </div>
# </details>

# %% [markdown]
# ## How to use this lab
#
# This lab is built for **self-paced learning**. Every step is explained here.
# You work at your own speed, repeat any part, and move on when you are ready.
# Learning from a notebook is itself an engineering skill: it is how you pick up every new tool after you graduate.
#
# | Symbol | Meaning |
# |---|---|
# | 🟢 | Run this code cell: click inside it and press **Shift + Enter**. |
# | ✏️ **Your turn** | A cell where you write or change code. The comment `# ✏️` marks the line. |
# | ✅ `check(...)` | The last line of every exercise. The "checker" prints ✅ for a right answer, or ❌ with a hint. |
# | 💡 Hint | Click the grey arrow to open a hint. Try first, then open it. |
# | 🔑 Still stuck? The code | The answer's code. Open it only after the hint, and make sure you understand each part. |
# | 🌐 | The Arabic translation of the section above it. Open it whenever it helps. |
#
# **Rules that save you an hour**
# - Run the cells **in order, top to bottom**. A cell can only use what earlier cells created.
# - If something strange happens, use **Runtime → Restart session and run all**. That fixes most problems.
# - Save your own copy first: **File → Save a copy in Drive**. Without it, your work is lost when you close the tab.
#
# **Stuck? That is where the learning happens.** Try these, in order:
# 1. Read the **last line** of the error message. It usually says exactly what is wrong.
# 2. Open the 💡 hint, and the 🌐 translation if a word is unclear.
# 3. Ask your classmates, in your class group or course forum. Name the part, paste the error, and say what you tried. A classmate has probably met the same wall.
# 4. **Be the one who helps.** Solved something tricky? Share how. Two lines from you can save a classmate an hour.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **كيف تستخدم هذا اللاب**
#
# صُمّم هذا اللاب **للتعلم الذاتي**. كل خطوة مشروحة هنا.
# تتقدم بالسرعة التي تناسبك، وتعيد أي جزء متى شئت، وتنتقل حين تكون جاهزاً.
# والتعلم من دفتر كهذا مهارة هندسية بحد ذاتها: بها تتعلم كل أداة جديدة بعد تخرجك.
#
# | الرمز | معناه |
# |---|---|
# | 🟢 | شغّل خلية الكود هذه: انقر داخلها واضغط **Shift + Enter**. |
# | ✏️ **دورك** | خلية تكتب فيها كوداً أو تعدّله. التعليق ⁦`# ✏️`⁩ يدلّك على السطر. |
# | ✅ ⁦`check(...)`⁩ | آخر سطر في كل تمرين. يطبع «المدقق» ✅ للإجابة الصحيحة، أو ❌ مع تلميح. |
# | 💡 تلميح | انقر السهم الرمادي لفتح التلميح. حاول أولاً ثم افتحه. |
# | 🔑 ما زلت عالقاً؟ الكود | كود الإجابة. لا تفتحه إلا بعد التلميح، وتأكد أنك تفهم كل جزء منه. |
# | 🌐 | الترجمة العربية للقسم الذي فوقها. افتحها متى أفادتك. |
#
# **قواعد توفّر عليك ساعة**
#
# - شغّل الخلايا **بالترتيب من الأعلى إلى الأسفل**؛ الخلية لا تستطيع استخدام إلا ما أنشأته الخلايا التي قبلها.
# - إن حدث شيء غريب، اختر **Runtime ثم Restart session and run all**؛ هذا يحل معظم المشاكل.
# - احفظ نسختك أولاً: **File ثم Save a copy in Drive**؛ فبدونها يضيع عملك عند إغلاق الصفحة.
#
# **واجهتك مشكلة؟ هنا يحدث التعلم الحقيقي.** جرّب بالترتيب:
# 1. اقرأ **السطر الأخير** من رسالة الخطأ، فهو غالباً يقول بالضبط ما المشكلة.
# 2. افتح 💡 التلميح، و🌐 الترجمة إن كانت كلمة غير واضحة.
# 3. اسأل زملاءك في مجموعة الشعبة أو منتدى المقرر. اذكر الجزء، والصق رسالة الخطأ، وقل ماذا جرّبت. غالباً مرّ زميل لك بالمشكلة نفسها.
# 4. **كن المبادر.** حللت مشكلة صعبة؟ شارك زملاءك طريقتك. سطران منك قد يوفّران ساعة على زميل.
#
# </div>
# </details>

# %% [markdown]
# ---
# # Part 1 · Colab in five minutes
#
# Colab is a Jupyter notebook that runs on Google's computers. You need only a browser and a Google account.
# Nothing is installed on your laptop, so you start quickly and safely.
#
# A notebook has two kinds of cells:
# - **Text cells** like this one. Double-click to see how they are written; press Shift + Enter to show them again.
# - **Code cells** like the one below. The number that appears on the left, `[1]`, is the order in which cells ran.
#
# 🟢 Run the cell below.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **الجزء 1 · Colab في خمس دقائق**
#
# Colab دفتر Jupyter يعمل على أجهزة Google. لا تحتاج إلا متصفحاً وحساب Google.
# ولا يُثبَّت شيء على جهازك، فتبدأ بسرعة وأمان.
#
# في الدفتر نوعان من الخلايا:
# - **خلايا نصية** مثل هذه. انقرها مرتين لترى كيف كُتبت، ثم اضغط Shift + Enter لتعود كما كانت.
# - **خلايا كود** مثل الخلية التالية. الرقم الذي يظهر على يسارها، مثل ⁦`[1]`⁩، هو ترتيب تشغيل الخلايا.
#
# 🟢 شغّل الخلية التالية.
#
# </div>
# </details>

# %%
print("Hello from Colab. This line ran on a computer in a Google data centre.")
1 + 1

# %% [markdown]
# Two things happened: `print(...)` wrote a line, and the **last line** of the cell (`1 + 1`) was shown automatically as `2`.
# You use both all semester: `print` for several results, the last line for one.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# حدث شيئان: ⁦`print(...)`⁩ كتبت سطراً، و**السطر الأخير** في الخلية (⁦`1 + 1`⁩) عُرضت نتيجته تلقائياً ⁦`2`⁩.
# تستخدم الاثنين طوال الفصل: ⁦`print`⁩ لعدة نتائج، والسطر الأخير لنتيجة واحدة.
#
# </div>
# </details>

# %% [markdown]
# ---
# # Part 2 · The Python this course needs (about 45 minutes)
#
# You do not need to become a programmer. You need to read short code, change a number or a column name, and write a line or two.
# This part teaches exactly that, on the smallest possible AI example.
#
# **The example.** A model is a rule with adjustable numbers. The simplest one predicts a transformer's loading from the air temperature with a straight line:
# `loading = w × temp + b`. Here `loading` is in % of the transformer's rating, `w` is how many points of loading each extra °C adds (air conditioning), and `b` is the loading the line gives at 0 °C.
# To judge a rule you measure its **error** on past readings. To improve it you adjust `w` and `b` in the direction that makes the error smaller.
# One such adjustment is called a **gradient step**; the lecture *How a Machine Learns* shows where it comes from.
# Here you only compute the error before and after one step, on three past readings:
#
# | air temperature (°C) | loading (% of rating) |
# |---|---|
# | 30 | 45 |
# | 40 | 65 |
# | 50 | 80 |
#
# ### 2.1 Variables and numbers
# A variable is a name for a value. `=` means *store*, not *equals*.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **الجزء 2 · بايثون الذي يحتاجه المقرر (نحو 45 دقيقة)**
#
# لست مطالباً بأن تصبح مبرمجاً. تحتاج أن تقرأ كوداً قصيراً، وتغيّر رقماً أو اسم عمود، وتكتب سطراً أو سطرين.
# هذا الجزء يعلّمك ذلك بالضبط، على أصغر مثال ممكن من الذكاء الاصطناعي.
#
# **المثال.** النموذج قاعدة فيها أرقام قابلة للتعديل. أبسط نموذج يتنبأ بنسبة تحميل المحوّل من درجة حرارة الهواء بخط مستقيم:
# ⁦`loading = w × temp + b`⁩. هنا ⁦`loading`⁩ نسبة التحميل (% من القدرة المقنّنة)، و⁦`w`⁩ عدد النقاط التي تضيفها كل درجة مئوية إضافية (التكييف)، و⁦`b`⁩ التحميل الذي يعطيه الخط عند 0 °م.
# لتحكم على القاعدة تقيس **خطأها** على قراءات سابقة. ولتحسّنها تعدّل ⁦`w`⁩ و⁦`b`⁩ في الاتجاه الذي يقلل الخطأ.
# والتعديل الواحد يسمى **خطوة تدرّج** (gradient step)؛ ومحاضرة *كيف تتعلم الآلة* تشرح من أين تأتي.
# هنا تحسب الخطأ فقط قبل خطوة واحدة وبعدها، على ثلاث قراءات سابقة:
#
# | درجة حرارة الهواء (°م) | نسبة التحميل (% من القدرة المقنّنة) |
# |---|---|
# | 30 | 45 |
# | 40 | 65 |
# | 50 | 80 |
#
# **2.1 المتغيرات والأرقام**
#
# المتغير اسم لقيمة. العلامة ⁦`=`⁩ تعني *احفظ*، لا *يساوي*.
#
# </div>
# </details>

# %%
w = 1.5        # weight: points of loading per °C
b = 0          # bias: the loading the line gives at 0 °C
temp = 30      # air temperature, °C
guess = w * temp + b
guess

# %% [markdown]
# The model above, `loading = w × temp + b`, is one line of Python. `*` is multiplication, `**` is a power (`3 ** 2` is 9).
# Text after `#` is a comment for humans; Python ignores it.
#
# ### 2.2 Lists: many values under one name
# A list holds values in order, inside square brackets. `len(...)` counts them, `sum(...)` adds them, and `max(...)` finds the largest.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# النموذج أعلاه، ⁦`loading = w × temp + b`⁩، سطر واحد في بايثون. ⁦`*`⁩ للضرب، و⁦`**`⁩ للأس (⁦`3 ** 2`⁩ تساوي 9).
# النص بعد ⁦`#`⁩ تعليق للبشر، يتجاهله بايثون.
#
# **2.2 القوائم: قيم كثيرة تحت اسم واحد**
#
# القائمة تحفظ القيم بالترتيب بين قوسين مربعين. ⁦`len(...)`⁩ تعدّها، و⁦`sum(...)`⁩ تجمعها، و⁦`max(...)`⁩ تجد أكبرها.
#
# </div>
# </details>

# %%
temp_c      = [30, 40, 50]     # the three past readings in the table above
loading_pct = [45, 65, 80]
print("rows:", len(temp_c), "  hottest:", max(temp_c), "°C", "  mean loading:", sum(loading_pct) / len(loading_pct))
print("first loading:", loading_pct[0], "  last loading:", loading_pct[-1])   # counting starts at 0

# %% [markdown]
# ### 2.3 One step for every row
# `zip` walks two lists side by side. A **list comprehension** builds a new list in one line:
# `[expression for item in list]` reads as *"the expression, for every item"*.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **2.3 خطوة واحدة لكل صف**
#
# ⁦`zip`⁩ تمرّ على قائمتين جنباً إلى جنب. و**list comprehension** تبني قائمة جديدة في سطر واحد:
# ⁦`[expression for item in list]`⁩ تُقرأ: *«هذا التعبير، لكل عنصر»*.
#
# </div>
# </details>

# %%
predictions = [w * t + b for t in temp_c]
misses      = [y - p for y, p in zip(loading_pct, predictions)]
print("predictions:", predictions)
print("misses:     ", misses)

# %% [markdown]
# ### ✏️ Your turn 1 · The first guess's error
# Compute the mean squared error (MSE) of the first guess: the average of the squared misses.
# Replace `None` with one line that computes it from the list `misses`.
# <details><summary>💡 Hint</summary>
#
# Square every miss, add the squares, and divide by how many misses there are. `sum(...)` adds and `len(...)` counts.
# </details>
# <details><summary>🔑 Still stuck? The code</summary>
#
# `[m ** 2 for m in misses]` gives the squared misses. Add them with `sum(...)` and divide by `len(misses)`.
# </details>
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **✏️ دورك 1 · خطأ التخمين الأول**
#
# احسب متوسط مربع الخطأ (MSE) للتخمين الأول: متوسط مربعات الأخطاء.
# استبدل ⁦`None`⁩ بسطر واحد يحسبه من القائمة ⁦`misses`⁩.
# <details><summary>💡 تلميح</summary>
#
# ربّع كل خطأ، واجمع المربعات، واقسم على عدد الأخطاء. ⁦`sum(...)`⁩ تجمع و⁦`len(...)`⁩ تعدّ.
# </details>
# <details><summary>🔑 ما زلت عالقاً؟ الكود</summary>
#
# ⁦`[m ** 2 for m in misses]`⁩ تعطيك مربعات الأخطاء. اجمعها بـ ⁦`sum(...)`⁩ واقسم على ⁦`len(misses)`⁩.
# </details>
#
# </div>
# </details>

# %%
#@title 🟢 Set up the answer checker (run this cell; no need to read it)
import hashlib, json

# Only fingerprints of the correct answers are stored here, never the answers themselves.
_LAB = "Lab01_First_Look_at_Data"
_ANSWERS = {'mse_first_guess': ('1dp', ['bccc01a68354494d'], 'Square every value in the list misses, add the squares, then divide by how many misses there are.'), 'mse_after_step': ('1dp', ['a3494126142b1c81'], 'Inside mse(w, b): the misses of p against loading_pct, then the mean of their squares, exactly as in Your turn 1.'), 'n_rows': ('int', ['40c0984095c0a233'], 'The number of rows of the table df; one of the five commands in 3.1 shows it.'), 'n_missing_code': ('int', ['5ba5f24162334676'], 'Compare the loading_pct column with -999 and count the True values, as in 3.2.'), 'n_zero_loading': ('int', ['e4fa5557c0f85a52'], 'Same pattern: compare loading_pct with 0 and count the True values.'), 'n_temp_impossible': ('int', ['3ae06cd421dbc16b'], 'The hottest air here is about 50 °C. Count the rows where temp_c is above 100.'), 'gap_days': ('int', ['f8eea8121203bcbb'], 'Take the time between each row and the one before it, find the largest, and express it in days.'), 'n_overload_filled': ('int', ['67a8367a0b52fe2d'], 'Count the rows where overload_report_time is not an empty string.'), 'baseline_mae': ('1dp', ['3d747a4d4b4b0683'], 'Take future minus loading on the both_real hours only, drop the sign (absolute value), then average.')}
_progress = {}

def _shown(value, kind):
    return str(int(round(value))) if kind == "int" else (f"{value:.2f}" if kind == "2dp" else f"{value:.1f}")

def check(name, value):
    """Tell you whether your answer is right, and give a hint if it is not."""
    kind, fingerprints, hint = _ANSWERS[name]
    try:
        v = float(value)
    except (TypeError, ValueError):
        print(f"❌ {name}: expected a number, got {value!r}.  Hint: {hint}")
        return
    shown = _shown(v, kind.rstrip("~"))
    if hashlib.sha256(f"ee3040|{_LAB}|{name}|{shown}".encode()).hexdigest()[:16] in fingerprints:
        print(f"✅ {name} = {shown}  Correct.")
        _progress[name] = shown
        return
    print(f"❌ {name} = {shown}  Not yet.  Hint: {hint}")

def _signature(*parts):
    """Short fingerprint of your email and answers. Change either, and it changes."""
    payload = "ee3040|lab01|" + "|".join(json.dumps(x, sort_keys=True, default=str) for x in parts)
    return hashlib.sha256(payload.encode()).hexdigest()[:12]

def _show(v):
    return v if v not in (None, "", []) else "missing"

print("Checker ready. Each ✏️ exercise ends with a check(...) line that confirms your answer or gives a hint.")

# %%
mse_first = None   # ✏️ replace None with your one-line calculation
check("mse_first_guess", mse_first)

# %% [markdown]
# ### 2.4 Functions: one name, many uses
# `def` defines a function. The indented lines are its body; `return` gives back the result.
# A function saves you from copying the same five lines ten times, so your code stays short and correct.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **2.4 الدوال: اسم واحد واستخدامات كثيرة**
#
# ⁦`def`⁩ تعرّف دالة. الأسطر المزاحة إلى الداخل هي جسمها، و⁦`return`⁩ تُرجع النتيجة.
# الدالة تغنيك عن نسخ الأسطر الخمسة نفسها عشر مرات، فيبقى كودك قصيراً وصحيحاً.
#
# </div>
# </details>

# %%
def predict(w, b, temps):
    """Straight-line model: one loading prediction per temperature."""
    return [w * t + b for t in temps]

predict(1.5, 0, temp_c)

# %% [markdown]
# ### ✏️ Your turn 2 · After one gradient step
# Compute the error of the line after one gradient step, by completing a function `mse(w, b)` that works for any `w` and `b`.
# The **slope** of the error says which way is downhill: here it is −300 for `w` and −6.67 for `b` (negative: making them larger lowers the error).
# A step moves each number against its slope, by the learning rate α times the slope. With α = 0.0002: `w = 1.5 − 0.0002 × (−300) = 1.56` and `b = 0 − 0.0002 × (−6.67) = 0.0013`.
# Is the new line better? Your function tells you by how much.
# <details><summary>💡 Hint</summary>
#
# Inside the function: the predictions `p` are already there. Compute the misses of `p` against `loading_pct`, then the mean of their squares, exactly as in Your turn 1, and `return` it.
# </details>
# <details><summary>🔑 Still stuck? The code</summary>
#
# `miss = [y - q for y, q in zip(loading_pct, p)]`, then `return sum(m ** 2 for m in miss) / len(miss)`.
# </details>
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **✏️ دورك 2 · بعد خطوة تدرّج واحدة**
#
# احسب خطأ الخط بعد خطوة تدرّج واحدة، بإكمال دالة ⁦`mse(w, b)`⁩ تعمل مع أي ⁦`w`⁩ و⁦`b`⁩.
# **ميل** الخطأ يدلّ على اتجاه النزول: هنا هو −300 لـ ⁦`w`⁩ و−6.67 لـ ⁦`b`⁩ (سالب: تكبيرهما يقلل الخطأ).
# الخطوة تحرّك كل رقم عكس ميله، بمقدار معدل التعلّم α مضروباً في الميل. مع α = 0.0002: ‏⁦`w = 1.5 − 0.0002 × (−300) = 1.56`⁩ و⁦`b = 0 − 0.0002 × (−6.67) = 0.0013`⁩.
# هل الخط الجديد أفضل؟ دالتك تخبرك بكم.
# <details><summary>💡 تلميح</summary>
#
# داخل الدالة: التنبؤات ⁦`p`⁩ جاهزة. احسب أخطاء ⁦`p`⁩ مقابل ⁦`loading_pct`⁩، ثم متوسط مربعاتها كما في دورك 1، وأرجعه بـ ⁦`return`⁩.
# </details>
# <details><summary>🔑 ما زلت عالقاً؟ الكود</summary>
#
# ⁦`miss = [y - q for y, q in zip(loading_pct, p)]`⁩، ثم ⁦`return sum(m ** 2 for m in miss) / len(miss)`⁩.
# </details>
#
# </div>
# </details>

# %%
def mse(w, b):
    p = predict(w, b, temp_c)
    # ✏️ compute and return the mean squared error of p against loading_pct
    return None

print("first guess:", mse(1.5, 0))
check("mse_after_step", mse(1.56, 0.0013))

# %% [markdown]
# ### 2.5 f-strings: numbers inside sentences
# Put `f` before the quotes and any `{expression}` inside is replaced by its value. `:.1f` means *one decimal place*, `:,` adds thousands separators.
# With it you write results the director reads quickly and clearly.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **2.5 صيغة f-string: أرقام داخل الجمل**
#
# ضع ⁦`f`⁩ قبل علامات التنصيص، وكل ⁦`{expression}`⁩ بداخلها تُستبدل بقيمتها. ⁦`:.1f`⁩ تعني *منزلة عشرية واحدة*، و⁦`:,`⁩ تضيف فواصل الآلاف.
# بها تكتب نتائج يقرؤها المدير بسرعة ووضوح.
#
# </div>
# </details>

# %%
before, after = mse(1.5, 0), mse(1.56, 0.0013)
too_big = mse(1.8, 0.0067)     # the same step with a learning rate five times larger, alpha = 0.001
if after is None:
    print("mse() still returns None: finish ✏️ Your turn 2, then run this cell again.")
else:
    print(f"One step with alpha = 0.0002 cut the error from {before:.1f} to {after:.1f}, a {100 * (1 - after / before):.0f}% drop.")
    print(f"The same step with alpha = 0.001 lands at w = 1.8, b = 0.0067, and the error grows to {too_big:.1f}: the step jumped past the bottom.")

# %% [markdown]
# That is all the Python this course needs from you directly. Everything else comes from **libraries**: code other people wrote that you load with `import`.
# The two you use most are **pandas** (tables) and **matplotlib** (plots).
#
# ---
# # Part 3 · The director's table
#
# **The question behind the table.** Every summer the same three distribution transformers (11/0.4 kV, 1,000 kVA, feeding dense housing) run above their loading limit in heat waves.
# Load is transferred too late.
#
# The limit is **100% of rating**: an administrative limit the utility sets, not a trip point.
# Distribution transformers are loaded above nameplate for a few hours at a time; the IEC 60076-7 and IEEE C57.91 loading guides allow it. The protection sits at about 1.25 to 1.5 times rated current.
# Running above the limit costs insulation loss of life, and in the worst case a failed unit, not an instant trip.
#
# Today the control room works from a **written rule**: *temperature above 46 °C and tie switch open: transfer load.*
# An engineer wrote it once. It ignores the time of day, the heat of the last few days and the neighbouring feeder.
# A **learned rule** is fitted from past readings instead. Before trying to learn one, an engineer asks three questions:
# 1. **Is there a pattern?** Yes: air-conditioning load follows the heat, and the same three transformers overload every summer.
# 2. **Is there a formula?** Partly: the IEC thermal model of a transformer needs hot-spot temperatures inside the winding that nobody measures here.
# 3. **Are there examples?** Hourly weather for eight years is fine. Most transformers have had load loggers only since 2020, a few since 2016. About 25 overload days in all is the weakness.
#
# So the honest answer to the director is *yes for a loading forecast, not yet for a model that predicts overloads directly*. The forecast starts from this table.
#
# The distribution department sent the hourly readings of the load logger on one of the three transformers, from **January 2021 to December 2024**:
#
# | Column | Meaning |
# |---|---|
# | `timestamp` | date and hour of the reading |
# | `temp_c` | air temperature in that hour, °C |
# | `temp_3h_c` | the logger's own mean of the air temperature over the last 3 hours, °C |
# | `neighbour_load_pct` | loading of the neighbouring feeder, % of its rating (it follows the same heat, about an hour later) |
# | `tie_closed` | 1 if the tie switch to the neighbouring feeder is closed, 0 if it is open. Normally it is **closed**: this transformer runs paralleled with the neighbouring feeder, which takes about a sixth of its load. The tie **opens for maintenance**, and then this transformer carries its whole load. |
# | `loading_pct` | loading of the transformer, % of its rating. **Above 100% (the utility's loading limit) it is overloaded.** |
# | `overload_report_time` | time the control room logged the overload, written by the control-room engineer after the event |
#
# > **This is a simulation, and we say so.** A small model generates the table: a daily load profile, air-conditioning load that follows the heat, and a tie switch, with realistic heat waves and realistic logger problems.
# > It behaves like the real thing and is the same on every student's computer; the course slides use the same numbers.
# > Your project uses **real** data (homework, Part 8).
#
# 🟢 Run the hidden cell below. It builds the table and stores it in a variable called `df` (short for *data frame*, pandas' word for a table).
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# هذا كل ما يحتاجه المقرر منك مباشرة في بايثون. كل ما عداه يأتي من **المكتبات**: كود كتبه غيرك تحمّله بـ ⁦`import`⁩.
# أكثر مكتبتين تستخدمهما: **pandas** للجداول و**matplotlib** للرسوم.
#
# **الجزء 3 · جدول المدير**
#
# **السؤال وراء الجدول.** كل صيف تتعرض المحوّلات الثلاثة نفسها من محوّلات التوزيع (11/0.4 كيلوفولت، 1,000 كيلوفولت أمبير، تغذي أحياء سكنية كثيفة) لتحميل فوق حدّه في موجات الحر.
# ويُنقل الحمل متأخراً.
#
# والحد هو **100% من القدرة المقنّنة**: حد تحميل إداري تضعه الشركة، لا نقطة فصل.
# محوّلات التوزيع تُحمَّل فوق قدرتها الاسمية بضع ساعات، ويسمح بذلك دليلا التحميل IEC 60076-7 وIEEE C57.91. والحماية مضبوطة عند نحو 1.25 إلى 1.5 ضعف التيار المقنّن.
# وثمن العمل فوق الحد هو تقادم العزل (فقدان عمر العزل)، وفي أسوأ الحالات تلف المحوّل، لا فصل فوري.
#
# غرفة التحكم تعمل اليوم **بقاعدة مكتوبة**: *الحرارة فوق 46 °م ومفتاح الربط مفتوح: انقل الحمل.*
# كتبها مهندس مرة واحدة. وهي تتجاهل ساعة اليوم وحرارة الأيام الماضية والمغذّي المجاور.
# أما **القاعدة المتعلَّمة** فتُستخرج من القراءات السابقة. وقبل محاولة تعلّم واحدة، يسأل المهندس ثلاثة أسئلة:
# 1. **هل يوجد نمط؟** نعم: حمل التكييف يتبع الحرارة، والمحوّلات الثلاثة نفسها يزيد حملها كل صيف.
# 2. **هل توجد معادلة؟** جزئياً: النموذج الحراري للمحوّل في معيار IEC يحتاج درجات حرارة النقطة الساخنة داخل الملفات، ولا أحد يقيسها هنا.
# 3. **هل توجد أمثلة؟** بيانات الطقس كل ساعة لثماني سنوات كافية. ومعظم المحوّلات لم تُركَّب عليها مسجّلات حمل إلا منذ 2020، وقليل منها منذ 2016. ونحو 25 يوم حمل زائد في المجموع هي نقطة الضعف.
#
# فالإجابة الصادقة للمدير: *نعم للتنبؤ بنسبة التحميل، وليس بعد لنموذج يتنبأ بالحمل الزائد مباشرة*. والتنبؤ يبدأ من هذا الجدول.
#
# أرسلت إدارة التوزيع قراءات كل ساعة من مسجّل الحمل على أحد المحوّلات الثلاثة، من **يناير 2021 إلى ديسمبر 2024**:
#
# | العمود | معناه |
# |---|---|
# | ⁦`timestamp`⁩ | تاريخ القراءة وساعتها |
# | ⁦`temp_c`⁩ | درجة حرارة الهواء في تلك الساعة، °م |
# | ⁦`temp_3h_c`⁩ | متوسط حرارة الهواء في آخر 3 ساعات كما يحسبه المسجّل نفسه، °م |
# | ⁦`neighbour_load_pct`⁩ | نسبة تحميل المغذّي المجاور، % من قدرته المقنّنة (يتبع الحرارة نفسها، بعدها بنحو ساعة) |
# | ⁦`tie_closed`⁩ | 1 إن كان مفتاح الربط مع المغذّي المجاور مغلقاً، و0 إن كان مفتوحاً. في الوضع العادي يكون **مغلقاً**: المحوّل يعمل على التوازي مع المغذّي المجاور، الذي يأخذ نحو سدس حمله. ويُفتح المفتاح **للصيانة**، وعندها يحمل المحوّل حمله كله وحده. |
# | ⁦`loading_pct`⁩ | نسبة تحميل المحوّل، % من قدرته المقنّنة. **فوق 100% (حد التحميل الذي تضعه الشركة) يكون في حمل زائد.** |
# | ⁦`overload_report_time`⁩ | وقت تسجيل غرفة التحكم للحمل الزائد، يكتبه مهندس غرفة التحكم بعد وقوعه |
#
# > **هذا الجدول محاكاة، ونقول ذلك صراحة.** يولّده نموذج مبسّط: منحنى الحمل اليومي، وحمل تكييف يتبع الحرارة، ومفتاح ربط، مع موجات حر واقعية ومشاكل مسجّلات واقعية.
# > يتصرف كالبيانات الحقيقية، ويأتي متطابقاً على جهاز كل طالب؛ وشرائح المقرر تستخدم الأرقام نفسها.
# > أما مشروعك فيستخدم بيانات **حقيقية** (الواجب، الجزء 8).
#
# 🟢 شغّل الخلية المخفية التالية. تبني الجدول وتحفظه في متغير اسمه ⁦`df`⁩ (اختصار *data frame*، وهي كلمة pandas للجدول).
#
# </div>
# </details>

# %%
#@title 🟢 Load the course data (run this cell; no need to read it)
import numpy as np
import pandas as pd

SEED = 3040
OVERLOAD_PCT = 100.0
HOT_MONTHS = [5, 6, 7, 8, 9]


def _temperature(hours, rng):
    """Hourly air temperature in °C for a hot, dry city: a seasonal wave, a daily cycle that
    peaks mid-afternoon, day-to-day weather that persists, and a few summer heat waves."""
    doy = hours.dayofyear.values
    hour = hours.hour.values
    season = 27.0 + 11.0 * np.sin(2 * np.pi * (doy - 110) / 365.25)
    daily = 6.0 * np.cos(2 * np.pi * (hour - 15) / 24)
    days = (hours.normalize() - hours[0].normalize()).days.values
    n_days = days.max() + 1
    anom = np.zeros(n_days)
    for d in range(1, n_days):                                  # weather persists for days
        anom[d] = 0.8 * anom[d - 1] + rng.normal(0, 1.0)
    day_ts = pd.date_range(hours[0].normalize(), periods=n_days, freq="D")
    summer = np.isin(day_ts.month, [6, 7, 8])
    for s in np.flatnonzero(summer & (rng.random(n_days) < 2.2 / 92)):   # about two heat waves a summer
        anom[s:s + int(rng.integers(3, 8))] += rng.uniform(2.0, 4.0)
    t = season + daily + anom[days] + rng.normal(0, 0.5, len(hours))
    return np.round(t, 1)


def _tie(hours, rng):
    """Tie switch to the neighbouring feeder: closed (1) except during maintenance windows,
    about ten a year, 6 to 30 hours each, when this transformer carries the whole load."""
    n = len(hours)
    closed = np.ones(n, dtype=int)
    for s in np.flatnonzero(rng.random(n) < 10 / 8760):
        closed[s:s + int(rng.integers(6, 31))] = 0
    return closed


# residential load shape by hour, as a fraction of the daily peak (evening peak, quiet dawn)
_PROFILE = np.array([.62, .56, .52, .49, .47, .47, .50, .55, .60, .64, .67, .70,
                     .72, .74, .76, .78, .80, .83, .88, .93, .96, .94, .85, .73])

TRANSFORMER = dict(base=42.0, ac=1.15, ac_start=24.0, ac_power=1.45, share=0.84, growth=0.02)


def _ramadan(hours):
    """Approximate Ramadan months for 2021-2025 (the evening peak moves later and grows)."""
    starts = {2021: "2021-04-13", 2022: "2022-04-02", 2023: "2023-03-23", 2024: "2024-03-11", 2025: "2025-03-01"}
    r = np.zeros(len(hours), dtype=bool)
    for y, s in starts.items():
        s = pd.Timestamp(s)
        r |= (hours >= s) & (hours < s + np.timedelta64(30, "D"))
    return r


def _simulate(hours, temp, tie, rng, p=TRANSFORMER):
    """Loading in % of rating, and the neighbouring feeder's loading."""
    n = len(hours)
    t = pd.Series(temp)
    felt = (0.45 * t + 0.55 * t.rolling(24, min_periods=1).mean()).values   # buildings store heat
    ac = p["ac"] * np.clip(felt - p["ac_start"], 0, None) ** p["ac_power"]
    shape = _PROFILE[hours.hour.values]
    weekend = np.isin(hours.dayofweek.values, [4, 5])                        # Friday and Saturday
    ram = _ramadan(hours)
    evening = np.isin(hours.hour.values, [20, 21, 22, 23, 0, 1])
    base = p["base"] * shape * np.where(weekend, 1.06, 1.0) * np.where(ram & evening, 1.15, 1.0)
    noise = np.zeros(n)
    for i in range(1, n):                                                    # slow, correlated noise
        noise[i] = 0.9 * noise[i - 1] + rng.normal(0, 1.1)
    years = (hours.year.values - 2021) + hours.dayofyear.values / 365.0
    demand = (base + ac * (0.55 + 0.45 * shape) + noise) * (1 + p.get("growth", 0.02)) ** years   # new customers every year
    loading = demand * np.where(tie == 1, p["share"], 1.0)
    neighbour = np.roll(0.9 * demand, 1) + rng.normal(0, 2.0, n)              # the neighbouring feeder follows the same heat, an hour later
    return np.round(np.clip(neighbour, 0, None), 1), np.round(np.clip(loading, 0, None), 1)


def _overload_events(loading):
    above = loading > OVERLOAD_PCT
    return int(np.sum(above[1:] & ~above[:-1]) + (1 if above[0] else 0))


def _overload_report_column(df):
    """Filled only on days the transformer overloaded: the time the control room logged the overload."""
    over = df["loading_pct"] > OVERLOAD_PCT
    first = df.loc[over].groupby(df.loc[over, "timestamp"].dt.date)["timestamp"].min()
    report = pd.Series("", index=df.index, dtype=object)
    day = df["timestamp"].dt.date
    for d, ts in first.items():
        report[day == d] = (ts + np.timedelta64(40, "m")).strftime("%H:%M")
    return report


def _add_mess(df, rng, gap=True):
    df = df.copy()
    n = len(df)
    val = df["loading_pct"].values.copy()
    # 1. bursts of the logger's 'no reading' code
    for s in rng.choice(n - 12, size=int(round(n * 0.0328 / 6)), replace=False):
        val[s:s + int(rng.integers(3, 10))] = -999.0
    # 2. dropouts to exactly zero
    for s in rng.choice(n - 14, size=max(2, int(round(n * 0.0092 / 9))), replace=False):
        val[s:s + int(rng.integers(6, 13))] = 0.0
    df["loading_pct"] = val
    # 3. three temperatures logged in tenths of a degree (history only)
    if gap:
        hot = np.flatnonzero((df["temp_c"].values > 45) & (df["temp_c"].values < 49))
        rows = rng.choice(hot, size=3, replace=False)
        df.loc[rows, "temp_c"] = (df.loc[rows, "temp_c"] * 10).round(0)
    # 4. the logger replacement: an 11-day gap, then a CT that reads 4% high (history only)
    if gap:
        cut0, cut1 = pd.Timestamp("2022-11-08"), pd.Timestamp("2022-11-19")
        df = df[(df["timestamp"] < cut0) | (df["timestamp"] >= cut1)].copy()
    after = df["timestamp"] >= pd.Timestamp("2022-11-19")
    real = df["loading_pct"] > 0
    df.loc[after & real, "loading_pct"] = (df.loc[after & real, "loading_pct"] * 1.04).round(1)
    return df.reset_index(drop=True)


def make_transformer(seed=SEED):
    rng = np.random.default_rng(seed)
    hours = pd.date_range("2021-01-01", "2025-12-31 23:00", freq="h")
    temp = _temperature(hours, rng)
    tie = _tie(hours, rng)
    neighbour, loading = _simulate(hours, temp, tie, rng)
    df = pd.DataFrame({"timestamp": hours, "temp_c": temp, "neighbour_load_pct": neighbour,
                       "tie_closed": tie, "loading_pct": loading})
    df["temp_3h_c"] = df["temp_c"].rolling(3, min_periods=1).mean().round(1)
    df["overload_report_time"] = _overload_report_column(df)
    df = df[["timestamp", "temp_c", "temp_3h_c", "neighbour_load_pct", "tie_closed", "loading_pct", "overload_report_time"]]
    hist = df[df["timestamp"] < "2025-01-01"].reset_index(drop=True)
    test = df[df["timestamp"] >= "2025-01-01"].reset_index(drop=True)
    return _add_mess(hist, rng, gap=True), _add_mess(test, rng, gap=False)


# ---------------------------------------------------------------------------
# Track D · the asset register (Lab 5). One row per transformer; answer = faults next summer.
def make_assets(seed=SEED + 1, n=900):
    """900 distribution transformers with their asset-register columns and the faults they had next summer."""
    rng = np.random.default_rng(seed)
    district = rng.choice(["North", "South", "East"], size=n, p=[0.45, 0.30, 0.25])
    age = rng.integers(1, 41, n)
    rating = rng.choice([500, 1000, 1500], size=n, p=[0.30, 0.50, 0.20])
    peak = np.round(np.clip(rng.normal(78, 14, n), 35, 130), 1)
    customers = np.round(rating * rng.uniform(0.18, 0.32, n)).astype(int)
    cable_age = rng.integers(1, 36, n)
    acetylene = np.round(rng.gamma(1.2, 1.6, n) + 6 * (rng.random(n) < 0.07), 1)   # a gas from arcing inside the oil
    fans = (rng.random(n) < 0.35).astype(int)                                   # forced cooling fitted
    # Faults come from thresholds and interactions (overloaded and old, arcing gas, old cables under
    # heavy loading, no fans on the busiest units): easy for trees, hard for a straight line.
    lam = np.exp(-0.2 + 1.1 * (1.0 * ((peak > 95) & (age > 20)) + 0.9 * (acetylene > 5)
                               + 0.7 * (age > 30) + 0.5 * ((cable_age > 25) & (peak > 85))
                               + 0.4 * ((fans == 0) & (peak > 100)))
                 + 0.15 * np.log1p(customers / 50) + 0.01 * age + 0.1 * (district == "South"))
    faults = rng.poisson(lam)
    return pd.DataFrame({
        "transformer_id": [f"T{i:03d}" for i in range(1, n + 1)],
        "district": district,
        "age_years": age,
        "rating_kva": rating,
        "peak_loading_pct": peak,
        "customers": customers,
        "cable_age_years": cable_age,
        "acetylene_ppm": acetylene,
        "cooling_fans": fans,
        "faults_last_3_summers": rng.poisson(1.5 * np.sqrt(lam) * rng.uniform(0.3, 1.7, n)),   # history helps, noisily
        "survey_batch": rng.integers(1, 60, n),
        "crew_hours_next_summer": np.round(np.clip(faults * 11.5 + rng.normal(0, 3, n), 0, None)),
        "faults_next_summer": faults,
    })


# ---------------------------------------------------------------------------
# Track C · forty transformer load loggers (Lab 6). Hourly loading for 2024, no labels.
LOGGER_ZONES = ["residential"] * 10 + ["commercial"] * 14 + ["government"] * 10 + ["farms"] * 6

_ZONE_SHAPE = {   # loading by hour as a fraction of the zone's daily peak
    "residential": _PROFILE,
    "commercial": np.array([.25, .20, .18, .17, .17, .18, .22, .35, .60, .80, .90, .95,
                            .95, .92, .90, .93, .97, 1.0, 1.0, .98, .92, .80, .55, .35]),
    "government": np.array([.20, .18, .17, .17, .17, .20, .40, .80, .95, 1.0, 1.0, 1.0,
                            .98, .95, .70, .40, .30, .27, .25, .24, .23, .22, .21, .20]),
    "farms": np.array([.70, .72, .74, .75, .75, .72, .60, .50, .48, .50, .55, .60,
                       .65, .66, .66, .64, .60, .58, .60, .64, .66, .68, .69, .70]),
}
_ZONE_PEAK = {"residential": 85.0, "commercial": 80.0, "government": 70.0, "farms": 60.0}


def make_loggers(seed=SEED + 2):
    """Hourly loading of 40 transformer loggers in 2024 (long format), and the maintenance log
    the operator 'forgot to mention'."""
    rng = np.random.default_rng(seed)
    hours = pd.date_range("2024-01-01", "2024-12-31 23:00", freq="h")
    n = len(hours)
    temp = _temperature(hours, rng)
    felt = pd.Series(temp).rolling(24, min_periods=1).mean().values
    heat = np.clip(felt - 22.0, 0, None) / 16.0
    frames = []
    for k in range(40):
        lid, zone = f"L{k + 1:02d}", LOGGER_ZONES[k]
        shape = _ZONE_SHAPE[zone][hours.hour.values]
        level = _ZONE_PEAK[zone] * rng.uniform(0.9, 1.1)
        load = level * shape * (0.45 + 0.55 * heat) + rng.normal(0, 1.2, n)
        frames.append(pd.DataFrame({"timestamp": hours, "logger_id": lid, "zone": zone, "loading_pct": load}))
    df = pd.concat(frames, ignore_index=True)
    # a few loggers get a problem each: finding them is the point of Lab 6
    stuck = (df.logger_id == "L17") & (df.timestamp >= "2024-02-03") & (df.timestamp < "2024-02-29")
    df.loc[stuck, "loading_pct"] = rng.normal(0.0, 0.2, int(stuck.sum()))
    df.loc[(df.logger_id == "L31") & (df.timestamp >= "2024-11-12"), "loading_pct"] += 4.0
    days = np.sort(rng.choice(np.arange(5, 360), size=14, replace=False))
    log = []
    for d in days:
        start = pd.Timestamp("2024-01-01") + np.timedelta64(int(d) * 24 + int(rng.integers(8, 12)), "h")
        end = start + np.timedelta64(int(rng.integers(4, 9)), "h")
        w = (df.logger_id == "L08") & (df.timestamp >= start) & (df.timestamp < end)
        df.loc[w, "loading_pct"] = np.abs(rng.normal(0.0, 0.3, int(w.sum())))
        log.append({"logger_id": "L08", "start": start, "end": end, "work": "switchgear maintenance, transformer de-energized"})
    df["loading_pct"] = df["loading_pct"].clip(lower=0).round(1)
    return df, pd.DataFrame(log)


# ---------------------------------------------------------------------------
# Twelve transformers in two districts (Lab 9): who does the model fail for?
SITES = ([(f"N{i}", "North", 2016 + i % 3) for i in range(1, 9)]
         + [(f"S{i}", "South", 2022) for i in range(1, 5)])


def make_network(seed=SEED + 3):
    """Hourly rows for 12 transformers, ready to model. Columns: site, district, logger_since,
    timestamp, the model inputs, and overload_in_6h (1 if the true loading passes 100% within the
    next six hours)."""
    rng = np.random.default_rng(seed)
    hours = pd.date_range("2021-01-01", "2025-12-31 23:00", freq="h")
    city_temp = _temperature(hours, rng)
    frames = []
    for site, district, since in SITES:
        local = np.round(city_temp + rng.normal(0, 0.4, len(hours)) + rng.uniform(-0.5, 0.5), 1)
        tie = _tie(hours, rng)
        south = district == "South"
        # South: denser blocks and older wiring, so load climbs faster in a short hot spell
        prm = dict(base=44.0 if south else 42.0, ac=1.2 if south else 1.15, ac_start=23.5 if south else 24.0,
                   ac_power=1.45, share=0.86 if south else 0.84, growth=0.02)
        neighbour, loading = _simulate(hours, local, tie, rng, prm)
        true_load = loading + rng.normal(0, 0.8, len(loading))
        # The overload label comes from the true loading; what each logger reads is another matter (Lab 9):
        # the southern loggers were installed with the wrong CT ratio setting and read about 10% low.
        seen = true_load * (0.90 if south else 1.0) + rng.normal(0, 2.5 if south else 0.0, len(loading))
        d = pd.DataFrame({"timestamp": hours, "temp_c": local, "neighbour_load_pct": neighbour,
                          "tie_closed": tie, "loading_pct": np.round(np.clip(seen, 0, None), 1)})
        d["temp_3h_c"] = d.temp_c.rolling(3, min_periods=1).mean()
        d["temp_24h_c"] = d.temp_c.rolling(24, min_periods=1).mean()
        d["hour"] = d.timestamp.dt.hour
        truth_s = pd.Series(true_load)
        fut = pd.concat([truth_s.shift(-k) for k in range(1, 7)], axis=1).max(axis=1)
        d["overload_in_6h"] = (fut > OVERLOAD_PCT).astype(int)
        d = d.iloc[:-6]
        d = d[d.timestamp >= pd.Timestamp(f"{since}-01-01")] if since >= 2021 else d
        d.insert(0, "logger_since", since)
        d.insert(0, "district", district)
        d.insert(0, "site", site)
        frames.append(d)
    return pd.concat(frames, ignore_index=True)


# ---------------------------------------------------------------------------
# Track B · thermal images (Lab 7): is there a hot spot on the equipment?
def _ironbow(x):
    """Map a temperature field scaled 0..1 to the false colours a thermal camera shows."""
    x = np.clip(x, 0, 1)
    r = np.clip(1.5 * x + 0.1, 0, 1)
    g = np.clip(2.2 * (x - 0.35), 0, 1)
    b = np.clip(0.6 - 1.8 * np.abs(x - 0.25), 0, 1) + np.clip(3 * (x - 0.85), 0, 1)
    return np.stack([r, g, np.clip(b, 0, 1)], axis=-1)


def make_thermal_images(n=1200, size=96, seed=SEED + 4):
    """Small false-colour thermal images (n, size, size, 3) of switchgear connections, taken on
    inspection rounds at three substations. Label 1 = hot spot (a connection far hotter than its
    neighbours), 0 = normal. A quarter of the normal images were taken in afternoon sun: the whole
    cabinet side is warm, but no connection stands out, the hard case. Each substation has its own
    cabinet layout and camera angle, which is why the data must be split by substation."""
    rng = np.random.default_rng(seed)
    yy, xx = np.mgrid[0:size, 0:size] / size
    images = np.zeros((n, size, size, 3), dtype=np.float32)
    labels = np.zeros(n, dtype=int)
    sites = np.array(["A", "B", "C"])[rng.integers(0, 3, n)]
    kinds = rng.choice(["hot", "normal", "sun"], size=n, p=[0.40, 0.36, 0.24])
    layout = {"A": (3, 0.30, 0.72), "B": (4, 0.25, 0.65), "C": (3, 0.35, 0.78)}   # bars, top, bottom
    for i in range(n):
        site, kind = sites[i], kinds[i]
        bars, top, bottom = layout[site]
        amb = rng.uniform(0.10, 0.30)
        rng.standard_normal((size, size))                                # an unused draw, kept so the images stay the same
        field = np.full((size, size), amb) + 0.06 * yy
        shift = rng.normal(0, 0.03)
        xs = np.linspace(0.25, 0.75, bars) + shift
        load = rng.uniform(0.08, 0.22)                                   # every bar warms with the load
        for bx in xs:                                                    # vertical bus bars
            bar = (np.abs(xx - bx) < 0.035) & (yy > top) & (yy < bottom)
            field = np.where(bar, amb + load + 0.03 * rng.normal(), field)
        for bx in xs:                                                    # bolted connections on each bar
            for cy in (top + 0.05, bottom - 0.05):
                spot = ((xx - bx) / 0.04) ** 2 + ((yy - cy) / 0.03) ** 2 < 1
                field = np.where(spot, field + load * 0.4, field)
        if kind == "sun":                                                # a warm wash from one side, no single hot joint
            side = rng.choice([-1, 1])
            wash = np.clip(0.5 + side * (xx - 0.5) * 1.6, 0, 1) * rng.uniform(0.25, 0.45)
            field = field + wash
        if kind == "hot":                                                # one connection far hotter than the rest
            bx = rng.choice(xs)
            cy = rng.choice([top + 0.05, bottom - 0.05])
            r = rng.uniform(0.025, 0.05)
            heat = np.exp(-(((xx - bx) ** 2 + (yy - cy) ** 2) / (2 * r ** 2)))
            field = field + rng.uniform(0.35, 0.6) * heat
            labels[i] = 1
        if rng.random() < 0.35:                                          # a reflection off the cabinet door
            y0 = rng.uniform(0.1, 0.9)
            field = np.where(np.abs(yy - y0) < 0.015, field + 0.12, field)
        field = field + rng.normal(0, 0.02, field.shape)
        images[i] = _ironbow(field)
    flip = rng.random(n) < 0.03                                          # a few labels are simply wrong
    labels[flip] = 1 - labels[flip]
    return (images * 255).astype(np.uint8), labels, sites, kinds


# ---------------------------------------------------------------------------
# The cleaning and feature steps students build in Lab 2, as one reference function.
# Later labs load the clean table with it, so every lab starts from the same known state.
FEATURES = ["temp_c", "temp_3h_c", "temp_6h_c", "temp_24h_c", "neighbour_load_pct", "tie_closed",
            "loading_pct", "loading_1h_ago", "loading_change_1h", "loading_max_24h", "hour", "month", "hot_season"]

history, test_2025 = make_transformer()
df = history.copy()
print(f'Course data loaded: {len(df):,} hourly rows from {df.timestamp.min():%d %b %Y} to {df.timestamp.max():%d %b %Y}.')

# %% [markdown]
# ### 3.1 Five first-look commands
# Run each cell and read the explanation under it. These five commands are the first thing to type on **any** new dataset, for the rest of your career.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **3.1 أوامر النظرة الأولى الخمسة**
#
# شغّل كل خلية واقرأ الشرح تحتها. هذه الأوامر الخمسة هي أول ما تكتبه على **أي** بيانات جديدة، طوال حياتك المهنية.
#
# </div>
# </details>

# %%
import pandas as pd
df.shape          # (rows, columns)

# %%
df.head()         # the first 5 rows. df.tail() shows the last 5; df.sample(5) shows 5 random rows

# %%
df.dtypes         # the type of each column

# %% [markdown]
# **Reading `dtypes`:** `datetime64` is a date and time (you can do arithmetic on it), `float64` is a decimal number, `int64` is a whole number, and `object` is text.
# A column you expected to be a number but shows `object` usually contains text such as `'n/a'` somewhere. Here the types are right, but that does **not** mean the values are.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **قراءة ⁦`dtypes`⁩:** ⁦`datetime64`⁩ تاريخ ووقت (يمكن إجراء عمليات حسابية عليه)، و⁦`float64`⁩ رقم عشري، و⁦`int64`⁩ عدد صحيح، و⁦`object`⁩ نص.
# إن كان عمود تتوقعه رقماً ويظهر ⁦`object`⁩، ففيه غالباً نص مثل ⁦`'n/a'`⁩ في مكان ما. الأنواع هنا صحيحة، لكن هذا **لا** يعني أن القيم صحيحة.
#
# </div>
# </details>

# %%
df.describe(include="number").round(1)     # count, mean, spread, min, quartiles, max of every number column

# %% [markdown]
# **Stop and read the `min` and `max` rows before going on.** Most data problems show up here.
# - Can a loading be **−999%**? Can it be **0.0** on a transformer that feeds homes day and night?
# - Can the air be **481 °C**? (The hottest hours here reach about 50 °C.) Compare it with the largest `temp_3h_c`, the logger's own 3-hour mean.
# - Look at the **mean** loading. Does 7.7% make sense for a transformer whose loading is 25 to 52% on half the hours (the 25% and 75% rows)? What pulled it down?
#
# Each of these is a real problem that silently ruins a model. In the next exercises you count them, accurately and one by one.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **توقف واقرأ صفَّي ⁦`min`⁩ و⁦`max`⁩ قبل أن تكمل.** هنا تظهر معظم مشاكل البيانات.
# - هل يمكن أن تكون نسبة التحميل **−999%**؟ وهل يمكن أن تكون **0.0** لمحوّل يغذي بيوتاً ليلاً ونهاراً؟
# - هل يمكن أن تكون حرارة الهواء **481 °م**؟ (أشد الساعات حرارة هنا تبلغ نحو 50 °م.) قارنها بأكبر قيمة في ⁦`temp_3h_c`⁩، متوسط الساعات الثلاث الذي يحسبه المسجّل نفسه.
# - انظر إلى **متوسط** التحميل. هل لقيمة 7.7% معنى لمحوّل تحميله بين 25 و52% في نصف الساعات (صفّا 25% و75%)؟ ما الذي سحبه إلى الأسفل؟
#
# كل واحدة من هذه مشكلة حقيقية تفسد النموذج بصمت. في التمارين التالية تعدّها واحدة واحدة، بدقة ووضوح.
#
# </div>
# </details>

# %%
df.isna().sum()     # empty cells per column

# %% [markdown]
# Zero empty cells, and yet the table is full of missing readings. **Missing data is often written as a number** (−999, 0, 9999) instead of left empty.
# `isna()` cannot see those. You look for them yourself.
#
# ### 3.2 Counting with a condition
# `df["loading_pct"] == -999` gives a column of `True`/`False`, one per row. `.sum()` counts the `True` values. This pattern answers almost every *"how many rows…?"* question.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# صفر خلايا فارغة، ومع ذلك الجدول مليء بالقراءات المفقودة. **كثيراً ما تُكتب القيمة المفقودة رقماً** (−999 أو 0 أو 9999) بدل أن تُترك فارغة.
# ⁦`isna()`⁩ لا تراها، فتبحث عنها بنفسك.
#
# **3.2 العدّ بشرط**
#
# ⁦`df["loading_pct"] == -999`⁩ تعطي عموداً من ⁦`True`⁩/⁦`False`⁩، قيمة لكل صف. و⁦`.sum()`⁩ تعدّ قيم ⁦`True`⁩. هذا النمط يجيب عن معظم أسئلة *«كم صفاً…؟»*.
#
# </div>
# </details>

# %%
(df["tie_closed"] == 0).sum()      # hours with the tie switch open

# %% [markdown]
# ### ✏️ Your turn 3 · Count the problems
# Count four things: the rows in the table, the loading readings of exactly −999, the loading readings of exactly 0, and the hours with an air temperature above 100 °C.
# Fill in each `None` with one line in the same pattern. Run and check: each `check` tells you if you are right.
# <details><summary>💡 Hint</summary>
#
# - The number of rows is one of the five commands in 3.1, or the Python function that counts things.
# - The other three follow the pattern of 3.2: a condition on a column, then count the `True` values.
# </details>
# <details><summary>🔑 Still stuck? The code</summary>
#
# - `n_rows`: `len(df)`
# - `n_missing_code`: `(df["loading_pct"] == -999).sum()`
# - The other two follow the same pattern with `== 0` and `> 100`.
# </details>
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **✏️ دورك 3 · عُدَّ المشاكل**
#
# عُدَّ أربعة أشياء: صفوف الجدول، وقراءات التحميل التي تساوي −999 تماماً، وقراءات التحميل التي تساوي 0 تماماً، والساعات التي تزيد فيها حرارة الهواء على 100 °م.
# املأ كل ⁦`None`⁩ بسطر واحد على النمط نفسه. شغّل وتحقّق: كل ⁦`check`⁩ تخبرك إن كانت إجابتك صحيحة.
# <details><summary>💡 تلميح</summary>
#
# - عدد الصفوف يظهر في أحد الأوامر الخمسة في 3.1، أو بدالة بايثون التي تعدّ العناصر.
# - الثلاثة الأخرى على نمط 3.2: شرط على عمود، ثم عدّ قيم ⁦`True`⁩.
# </details>
# <details><summary>🔑 ما زلت عالقاً؟ الكود</summary>
#
# - ⁦`n_rows`⁩: ‏⁦`len(df)`⁩
# - ⁦`n_missing_code`⁩: ‏⁦`(df["loading_pct"] == -999).sum()`⁩
# - الاثنان الآخران على النمط نفسه مع ⁦`== 0`⁩ و⁦`> 100`⁩.
# </details>
#
# </div>
# </details>

# %%
n_rows            = None   # ✏️ how many rows in the table
n_missing_code    = None   # ✏️ rows where loading_pct is exactly -999
n_zero_loading    = None   # ✏️ rows where loading_pct is exactly 0
n_temp_impossible = None   # ✏️ rows where temp_c is above 100

check("n_rows", n_rows)
check("n_missing_code", n_missing_code)
check("n_zero_loading", n_zero_loading)
check("n_temp_impossible", n_temp_impossible)

# %% [markdown]
# ### 3.3 Two plots
# Numbers hide what a picture shows at once. The first plot is the loading over four years; the second is loading against air temperature.
# The cell first hides the −999 rows with `df[df["loading_pct"] > -900]`: *keep only the rows where the condition is True*. It keeps the zero readings on purpose, so you see them.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **3.3 رسمان**
#
# الأرقام تخفي ما تكشفه الصورة فوراً. الرسم الأول نسبة التحميل عبر أربع سنوات، والثاني نسبة التحميل مقابل حرارة الهواء.
# تُخفي الخلية صفوف −999 أولاً بـ ⁦`df[df["loading_pct"] > -900]`⁩، أي: *احتفظ فقط بالصفوف التي يتحقق فيها الشرط*. وتُبقي قراءات الصفر عمداً لتراها.
#
# </div>
# </details>

# %%
import matplotlib.pyplot as plt

ok = df[df["loading_pct"] > -900]
fig, ax = plt.subplots(figsize=(12, 3.5))
ax.plot(ok["timestamp"], ok["loading_pct"], linewidth=0.6)
ax.axhline(100, color="red", linestyle="--", label="overloaded above 100% of rating")
ax.set_ylabel("loading (% of rating)")
ax.set_title("Four years of hourly loading readings")
ax.legend()
plt.show()

# %% [markdown]
# **What to see:** the loading follows the seasons: 20 to 40% on winter days, and every summer it climbs, with heat waves pushing it over the red line.
# 2023 was a mild summer: it touches the line for a single hour, and the next cells show why even that reading is suspect.
#
# The thin lines that drop straight to **0** are the zero dropouts you counted in Your turn 3. The logger stopped reporting; the customers did not switch everything off.
# A model reads them as an empty network. Ask the operator before deciding whether a zero is an outage or a dropout.
#
# Look also at **November 2022**. Two things happened there: a stretch of time with no readings at all, and a loading that, after the gap, reads a little higher than before.
#
# ### ✏️ Your turn 4 · The gap's length
# Find the largest jump in time between two rows of the table, in days.
# `df["timestamp"].diff()` gives the time between each row and the one before it. Normally that is one hour.
# <details><summary>💡 Hint</summary>
#
# Take the largest value of that column of time differences, then divide it by the length of one day.
# </details>
# <details><summary>🔑 Still stuck? The code</summary>
#
# `biggest = df["timestamp"].diff().max()` is a time span. Divide it by `pd.Timedelta(days=1)` to get a number of days.
# </details>
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **ما الذي تراه:** التحميل يتبع الفصول: 20 إلى 40% في أيام الشتاء، ويرتفع كل صيف، وموجات الحر تدفعه فوق الخط الأحمر.
# صيف 2023 كان معتدلاً: لم يلمس الخط إلا ساعة واحدة، والخلايا التالية تبيّن لماذا حتى تلك القراءة مشكوك فيها.
#
# الخطوط الرفيعة التي تهبط مباشرة إلى **0** هي انقطاعات الصفر التي عددتها في دورك 3. المسجّل توقف عن الإرسال، لا أن المشتركين أطفؤوا كل شيء.
# والنموذج يقرؤها شبكة فارغة. اسأل المشغّل قبل أن تقرر هل الصفر انقطاع كهرباء أم انقطاع في المسجّل.
#
# وانظر أيضاً إلى **نوفمبر 2022**. حدث هناك أمران: فترة بلا قراءات إطلاقاً، وتحميل يقرأ بعدها أعلى قليلاً مما كان قبلها.
#
# **✏️ دورك 4 · طول الفجوة**
#
# أوجد أكبر قفزة زمنية بين صفين في الجدول، بالأيام.
# ⁦`df["timestamp"].diff()`⁩ تعطي الزمن بين كل صف والصف الذي قبله، وهو عادة ساعة واحدة.
# <details><summary>💡 تلميح</summary>
#
# خذ أكبر قيمة في عمود فروق الزمن هذا، ثم اقسمها على طول يوم واحد.
# </details>
# <details><summary>🔑 ما زلت عالقاً؟ الكود</summary>
#
# ⁦`biggest = df["timestamp"].diff().max()`⁩ مدة زمنية. اقسمها على ⁦`pd.Timedelta(days=1)`⁩ لتحصل على عدد الأيام.
# </details>
#
# </div>
# </details>

# %%
gap_days = None   # ✏️
check("gap_days", gap_days)

# %%
nov = ok[(ok["timestamp"] >= "2022-10-20") & (ok["timestamp"] < "2022-12-10")]
fig, ax = plt.subplots(figsize=(12, 3))
ax.plot(nov["timestamp"], nov["loading_pct"], ".", markersize=2, label="this transformer")
ax.plot(nov["timestamp"], nov["neighbour_load_pct"], ".", markersize=2, alpha=0.4, label="neighbouring feeder")
ax.set_title("Zoom: 20 October to 10 December 2022")
ax.set_ylabel("loading (% of rating)")
ax.legend()
plt.show()

# The neighbouring feeder's meter was not touched, so compare this transformer with it (tie switch closed, real readings only)
shared = nov[(nov["tie_closed"] == 1) & (nov["loading_pct"] > 0)]
ratio = shared["loading_pct"] / shared["neighbour_load_pct"]
before_gap = ratio[shared["timestamp"] < "2022-11-08"].median()
after_gap = ratio[shared["timestamp"] >= "2022-11-19"].median()
print(f"loading / neighbouring feeder, median before the gap: {before_gap:.3f}, after the gap: {after_gap:.3f} "
      f"({100 * (after_gap / before_gap - 1):.1f}% higher)")

# %% [markdown]
# The logger was **replaced** in November 2022. For the days you measured in Your turn 4 there are no rows.
# The new current transformer (CT) reads **4% high**: the same load now shows 4% more.
#
# A plain before/after median hides this, because the weather changes over the same weeks.
# The neighbouring feeder lives through the same weather, so comparing with it shows the step.
# The medians against the neighbour give the 3.6% printed above, while the true step is about 4%: a ratio of two noisy meters over a few weeks only estimates the step.
#
# It is also why 2023's single hour above the red line is doubtful: 100.8% read by the new CT is about 97% of rating in reality.
# A model trained across that date learns a jump that never happened in the network. Lab 2 fixes it; today you only notice it.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# استُبدل المسجّل في نوفمبر 2022. طوال الأيام التي قستها في دورك 4 لا توجد صفوف.
# ومحوّل التيار (CT) الجديد يقرأ أعلى **بـ4%**: الحمل نفسه يظهر الآن أكبر بـ4%.
#
# المقارنة البسيطة بين الوسيط قبل الفجوة وبعدها تُخفي ذلك، لأن الطقس يتغير في الأسابيع نفسها.
# أما المغذّي المجاور فيعيش الطقس نفسه، فتكشف المقارنة به القفزة.
# الوسيطان مقابل المغذّي المجاور يعطيان 3.6% المطبوعة أعلاه، بينما القفزة الحقيقية نحو 4%: نسبة بين عدّادين فيهما ضجيج على بضعة أسابيع لا تعطي إلا تقديراً للقفزة.
#
# وهذا أيضاً سبب الشك في ساعة 2023 الوحيدة فوق الخط الأحمر: قراءة 100.8% من محوّل التيار الجديد تعادل في الواقع نحو 97% من القدرة المقنّنة.
# النموذج الذي يتدرب عبر ذلك التاريخ يتعلم قفزة لم تحدث في الشبكة أبداً. يصلحها اللاب 2؛ والمطلوب اليوم أن تلاحظها فقط.
#
# </div>
# </details>

# %%
fig, ax = plt.subplots(figsize=(6, 4))
real_temp = ok[(ok["temp_c"] < 100) & (ok["loading_pct"] > 0)]     # without the temperatures in tenths and the zero dropouts
ax.scatter(real_temp["temp_c"], real_temp["loading_pct"], s=3, alpha=0.3)
ax.axhline(100, color="red", linestyle="--")
ax.set_xlabel("air temperature (°C)")
ax.set_ylabel("loading (% of rating)")
ax.set_title("Loading against air temperature")
plt.show()

# %% [markdown]
# **What to see:** below about 25 °C the loading barely moves: lighting, fridges and pumps, no air conditioning.
# Above about 30 °C it climbs steeply as the air conditioners start, but **not always** by the same amount: at 40 to 45 °C the loading can be anywhere from about 60% to over 100%.
#
# That spread is exactly why the director needs a model and not a single threshold on temperature like the written rule.
# Other columns (tie switch open, several hot days in a row, the evening peak) explain part of it. The coming labs model that.
#
# ### ✏️ Your turn 5 · A column from the future
# Count the rows where `overload_report_time` is filled, then answer the question in the text cell below.
# The column `overload_report_time` is filled only on days the transformer overloaded; on other rows it holds an empty string `""`.
# <details><summary>💡 Hint</summary>
#
# A condition on the column, "is not an empty string", then count the `True` values, as in 3.2.
# </details>
# <details><summary>🔑 Still stuck? The code</summary>
#
# `(df["overload_report_time"] != "").sum()`: `!=` means *is not equal to*.
# </details>
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **ما الذي تراه:** تحت نحو 25 °م يكاد التحميل لا يتحرك: إنارة وثلاجات ومضخات، بلا تكييف.
# وفوق نحو 30 °م يرتفع بحدة مع تشغيل المكيفات، لكن **ليس دائماً** بالمقدار نفسه: عند 40 إلى 45 °م قد يكون التحميل بين نحو 60% وأكثر من 100%.
#
# هذا التشتت هو بالضبط سبب حاجة المدير إلى نموذج لا إلى عتبة واحدة على الحرارة كالقاعدة المكتوبة.
# أعمدة أخرى (مفتاح الربط مفتوح، عدة أيام حارة متتالية، ذروة المساء) تفسّر جزءاً منه، واللابات القادمة تبني نموذجاً لذلك.
#
# **✏️ دورك 5 · عمود من المستقبل**
#
# عُدَّ الصفوف التي فيها ⁦`overload_report_time`⁩ مملوء، ثم أجب عن السؤال في الخلية النصية التالية.
# العمود ⁦`overload_report_time`⁩ لا يُملأ إلا في الأيام التي تعرّض فيها المحوّل لحمل زائد؛ وفي بقية الصفوف فيه نص فارغ ⁦`""`⁩.
# <details><summary>💡 تلميح</summary>
#
# شرط على العمود، «ليس نصاً فارغاً»، ثم عدّ قيم ⁦`True`⁩ كما في 3.2.
# </details>
# <details><summary>🔑 ما زلت عالقاً؟ الكود</summary>
#
# ⁦`(df["overload_report_time"] != "").sum()`⁩: العلامة ⁦`!=`⁩ تعني *لا يساوي*.
# </details>
#
# </div>
# </details>

# %%
n_overload_filled = None   # ✏️ rows where overload_report_time is not an empty string ""
check("n_overload_filled", n_overload_filled)

# %% [markdown]
# **Question (write your answer in the findings table in Part 4):** the control-room engineer writes `overload_report_time` **after** the overload.
# The column is filled on every hour of that day, even the hours before the overload.
# Give this column to a model that must warn of overloads six hours ahead: what does its test score look like, and what happens in the first real heat wave?
# <details><summary>💡 Answer, after you have written yours</summary>
#
# The model learns *"overload_report_time is filled → overload"*. Its score on past data looks almost perfect.
# In real use it is useless, because six hours before an overload nobody has logged the overload yet.
# This is **data leakage**: a column that contains the answer. Drop it before training. Always ask of every column: *will I really have this value at the moment of prediction?*
# </details>
#
# **Where you are now:** `df` is still the raw table, unchanged; `ok` is the same table without the −999 rows; your counts are stored in `n_rows`, `n_missing_code`, `n_zero_loading`, `n_temp_impossible`, `gap_days` and `n_overload_filled`.
#
# ---
# # Part 4 · The findings table
#
# A first look is only useful when it is written down. Engineers keep a **findings table**: what you saw, how many rows, what it means, and what you do about it.
# Each row turns an observation into a decision, clearly and traceably.
#
# ### ✏️ Your turn 6 · Your findings table
# Write one row for each of the five problems you found in Part 3, in your own words.
# The first row is an example of a finding that is **not** an error: an unusual value that is real and must be kept.
# The five rows below it are ready. Fill in the text between the quotes and the number of rows (you counted most of them already).
# <details><summary>💡 Hint</summary>
#
# For `"rows"` you can type a number or reuse your variables, for example `n_missing_code`. For the gap, the number of missing hours is about 24 times the days you found.
# </details>
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **سؤال (اكتب إجابتك في جدول الملاحظات في الجزء 4):** مهندس غرفة التحكم يكتب ⁦`overload_report_time`⁩ **بعد** وقوع الحمل الزائد.
# والعمود يُملأ في كل ساعات ذلك اليوم، حتى الساعات التي قبل الحمل الزائد.
# أعطِ هذا العمود لنموذج يجب أن ينذر بالحمل الزائد قبل ست ساعات: كيف تبدو نتيجته في الاختبار، وماذا يحدث في أول موجة حر حقيقية؟
# <details><summary>💡 الإجابة، بعد أن تكتب إجابتك</summary>
#
# يتعلم النموذج أن *«امتلاء overload_report_time يعني حملاً زائداً»*. تبدو نتيجته على البيانات السابقة مثالية تقريباً.
# وفي الاستخدام الفعلي يكون عديم الفائدة، لأن غرفة التحكم لم تسجّل الحمل الزائد بعد قبل وقوعه بست ساعات.
# هذا هو **تسرّب البيانات** (data leakage): عمود يحتوي على الإجابة. احذفه قبل التدريب، واسأل دائماً عن كل عمود: *هل سأملك هذه القيمة فعلاً لحظة التنبؤ؟*
# </details>
#
# **أين وصلت الآن:** ⁦`df`⁩ ما زال الجدول الخام دون تغيير؛ و⁦`ok`⁩ الجدول نفسه دون صفوف −999؛ وأعدادك محفوظة في ⁦`n_rows`⁩ و⁦`n_missing_code`⁩ و⁦`n_zero_loading`⁩ و⁦`n_temp_impossible`⁩ و⁦`gap_days`⁩ و⁦`n_overload_filled`⁩.
#
# **الجزء 4 · جدول الملاحظات**
#
# النظرة الأولى لا تنفع إلا إذا كُتبت. المهندسون يحتفظون **بجدول ملاحظات**: ما رأيت، وكم صفاً، وما معناه، وماذا تفعل حياله.
# كل صف يحوّل ملاحظة إلى قرار، بوضوح وقابلية للتتبع.
#
# **✏️ دورك 6 · جدول ملاحظاتك**
#
# اكتب صفاً لكل واحدة من المشاكل الخمس التي وجدتها في الجزء 3، بكلماتك.
# الصف الأول مثال لملاحظة **ليست** خطأً: قيمة غير معتادة لكنها حقيقية ويجب الاحتفاظ بها.
# والصفوف الخمسة تحته جاهزة. املأ النص بين علامات التنصيص وعدد الصفوف (عددت معظمها من قبل).
# <details><summary>💡 تلميح</summary>
#
# في ⁦`"rows"`⁩ تستطيع كتابة رقم أو استخدام متغيراتك، مثل ⁦`n_missing_code`⁩. وللفجوة، عدد الساعات المفقودة نحو 24 ضعف عدد الأيام التي وجدتها.
# </details>
#
# </div>
# </details>

# %%
findings = [
    {"what I found": "tie_closed is 0 for some hours",
     "rows": int((df["tie_closed"] == 0).sum()),
     "what it means": "tie switch opened for maintenance: a real condition, not a logger error",
     "what I will do": "keep it; the model needs to know when the transformer carries the whole load"},
    # ✏️ fill in the five rows below: text between the quotes, a number after "rows"
    {"what I found": "", "rows": None, "what it means": "", "what I will do": ""},   # ✏️ the -999 readings
    {"what I found": "", "rows": None, "what it means": "", "what I will do": ""},   # ✏️ the zero readings
    {"what I found": "", "rows": None, "what it means": "", "what I will do": ""},   # ✏️ the temperatures above 100 °C
    {"what I found": "", "rows": None, "what it means": "", "what I will do": ""},   # ✏️ the November 2022 gap and the 4% CT offset
    {"what I found": "", "rows": None, "what it means": "", "what I will do": ""},   # ✏️ overload_report_time
]
pd.DataFrame(findings)

# %% [markdown]
# ---
# # Part 5 · The baseline to beat
#
# Before any model, compute the **baseline**: the error of the simplest reasonable forecast.
# For a six-hour loading forecast, that forecast is **"the loading in six hours equals the loading now."**
# A model that cannot beat it has learned nothing, however clever it looks.
#
# The error here is the **mean absolute error (MAE)**: the average size of the miss, in % of rating. Three steps:
# 1. For every hour, find the loading six hours later. `shift(-6, freq="h")` moves the series six hours back in time, so each row sees its future.
# 2. Keep only the hours where **both** loadings are real readings (above 0): this drops −999 and the zero dropouts.
# 3. Average the absolute difference.
#
# ### ✏️ Your turn 7 · The baseline error
# Compute the baseline MAE: step 3, the average size of the miss of "same as now" on the hours where both loadings are real.
# The cell already does steps 1 and 2. Read those lines, then write step 3 in place of `None`.
# <details><summary>💡 Hint</summary>
#
# The miss on each hour is `future` minus `loading`. Keep only the `both_real` hours, drop the sign with `.abs()`, then take the `.mean()`.
# </details>
# <details><summary>🔑 Still stuck? The code</summary>
#
# `(future[both_real] - loading[both_real]).abs().mean()`
# </details>
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **الجزء 5 · خط الأساس المطلوب تجاوزه**
#
# قبل أي نموذج، احسب **خط الأساس**: خطأ أبسط توقع معقول.
# للتنبؤ بنسبة التحميل بعد ست ساعات، هذا التوقع هو **«التحميل بعد ست ساعات يساوي التحميل الآن»**.
# والنموذج الذي لا يتفوق عليه لم يتعلم شيئاً، مهما بدا ذكياً.
#
# الخطأ المستخدم هنا هو **متوسط الخطأ المطلق (MAE)**: متوسط حجم الخطأ، بنسبة مئوية من القدرة المقنّنة. ثلاث خطوات:
# 1. لكل ساعة، أوجد التحميل بعد ست ساعات. ⁦`shift(-6, freq="h")`⁩ تزيح السلسلة ست ساعات إلى الخلف، فيرى كل صف مستقبله.
# 2. احتفظ فقط بالساعات التي تكون فيها **كلتا** القيمتين قراءة حقيقية (أكبر من 0)؛ هذا يحذف −999 وانقطاعات الصفر.
# 3. احسب متوسط الفرق المطلق.
#
# **✏️ دورك 7 · خطأ خط الأساس**
#
# احسب MAE لخط الأساس: الخطوة 3، أي متوسط حجم خطأ «مثل الآن» في الساعات التي تكون فيها القيمتان حقيقيتين.
# الخلية تنفّذ الخطوتين 1 و2. اقرأ هذه الأسطر، ثم اكتب الخطوة 3 مكان ⁦`None`⁩.
# <details><summary>💡 تلميح</summary>
#
# الخطأ في كل ساعة هو ⁦`future`⁩ ناقص ⁦`loading`⁩. احتفظ بساعات ⁦`both_real`⁩ فقط، وأزل الإشارة بـ ⁦`.abs()`⁩، ثم خذ ⁦`.mean()`⁩.
# </details>
# <details><summary>🔑 ما زلت عالقاً؟ الكود</summary>
#
# ⁦`(future[both_real] - loading[both_real]).abs().mean()`⁩
# </details>
#
# </div>
# </details>

# %%
loading = df.set_index("timestamp")["loading_pct"]
future  = loading.shift(-6, freq="h").reindex(loading.index)   # step 1: the loading six hours after each row
both_real = (loading > 0) & (future > 0)                       # step 2: True where both are real readings
print(f"Hours where both loadings are real: {both_real.sum():,}")

baseline_mae = None   # ✏️ step 3: the average absolute difference between future and loading, on the both_real hours
check("baseline_mae", baseline_mae)

# %% [markdown]
# Six hours is a long time for a transformer. Between mid-afternoon and the evening peak the loading alone moves by tens of points, so even the average miss is not small.
# But the average hides the hours the director cares about: the climbs before an overload.
# 🟢 Run the next cell. It shows the same baseline **only on hours when the loading is rising fast**, and on the hours just before an overload.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# ست ساعات مدة طويلة في حياة محوّل. بين منتصف العصر وذروة المساء يتحرك التحميل وحده عشرات النقاط، لذلك حتى متوسط الخطأ ليس صغيراً.
# لكن المتوسط يُخفي الساعات التي تهم المدير: الصعود الذي يسبق الحمل الزائد.
# 🟢 شغّل الخلية التالية. تعرض خط الأساس نفسه **فقط في الساعات التي يرتفع فيها التحميل بسرعة**، وفي الساعات التي تسبق الحمل الزائد مباشرة.
#
# </div>
# </details>

# %%
rising = both_real & ((future - loading) > 20)
print(f"On the {rising.sum():,} hours before a rise of more than 20 points, the baseline is off by "
      f"{(future[rising] - loading[rising]).abs().mean():.1f}% of rating on average.")

before_overload = both_real & (future > 100)
said_fine = (loading[before_overload] <= 100).sum()
print(f"On the {before_overload.sum()} hours whose loading six hours later is above 100%, "
      f"'same as now' forecasts no overload on {said_fine} of them.")

# %% [markdown]
# **The baseline's lesson:** on the hours that matter its miss is about twice its average, and before most overloads it says the transformer is fine.
# Keep both numbers. From Lab 3 on, every model you build is reported next to them, accurately and honestly.
#
# ---
# # Part 6 · Your AI assistant (about 30 minutes)
#
# A large language model (LLM) explains code, suggests the next step, and drafts code for you. It can also invent numbers with total confidence.
# In this course you use one in every lab **the way an engineer should**: ask it, then check what it says against the data.
# That is how the assistant makes you faster and keeps you accurate.
#
# The lab uses **Groq**, a service that runs Meta's open **Llama** models and gives a **free API key** to students.
# *Free* means limited: at the time of writing, about 30 requests a minute and 1,000 a day for the Llama models, far more than a lab needs.
# Limits change; the page *console.groq.com/settings/limits* shows yours.
#
# ### 6.1 Get a free key (5 minutes, once for the whole semester)
# 1. Open **https://console.groq.com** and sign in with your Google account or an email address.
# 2. In the left menu open **API Keys**, then click **Create API Key**. Name it `ee3040`.
# 3. **Copy the key now.** It starts with `gsk_` and is shown only once. If you lose it, delete it and create a new one.
#
# ### 6.2 Store the key safely (never in a cell)
# A key is a password that spends someone's quota. Anyone who sees your notebook sees every cell, so **the key must never be written in a cell**.
# 1. In the left sidebar of Colab click the **key icon (🔑 Secrets)**.
# 2. Click **Add new secret**. Name: `GROQ_API_KEY`. Value: paste your key.
# 3. Switch on **Notebook access** for this secret.
#
# That is all. The next cell reads the key from the secret store, so your notebook never contains it: your work stays shareable and your key stays safe.
#
# **No key yet, or Groq not reachable from your network?** You can still finish this part.
# When no key is set up, or the service does not answer, `ask` returns a **saved example answer**, clearly marked, so Your turns 8 and 9 work the same way.
# Add a key later and run the cells again to see a live answer.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **درس خط الأساس:** في الساعات التي تهم يبلغ خطؤه نحو ضعف متوسطه، وقبل معظم حالات الحمل الزائد يقول إن المحوّل بخير.
# احتفظ بالرقمين. من اللاب 3 فصاعداً، كل نموذج تبنيه يُعرض بجانبهما، بدقة وأمانة.
#
# **الجزء 6 · مساعدك الذكي (نحو 30 دقيقة)**
#
# نموذج اللغة الكبير (LLM) يشرح الكود، ويقترح الخطوة التالية، ويكتب لك مسودة كود. ويستطيع أيضاً أن يخترع أرقاماً بثقة تامة.
# في هذا المقرر تستخدمه في كل لاب **كما ينبغي للمهندس**: اسأله، ثم تحقق مما يقوله على البيانات.
# بهذا يسرّعك المساعد وتبقى نتائجك دقيقة.
#
# يستخدم اللاب خدمة **Groq**، التي تشغّل نماذج **Llama** المفتوحة من Meta وتعطي الطلاب **مفتاح API مجانياً**.
# *مجاني* يعني محدوداً: عند كتابة هذا اللاب، نحو 30 طلباً في الدقيقة و1,000 في اليوم لنماذج Llama، وهذا أكثر بكثير مما يحتاجه لاب.
# الحدود تتغير، وصفحة *console.groq.com/settings/limits* تعرض حدودك.
#
# **6.1 احصل على مفتاح مجاني (5 دقائق، مرة واحدة للفصل كله)**
#
# 1. افتح **https://console.groq.com** وسجّل الدخول بحساب Google أو ببريد إلكتروني.
# 2. من القائمة اليسرى افتح **API Keys**، ثم اضغط **Create API Key** وسمّه ⁦`ee3040`⁩.
# 3. **انسخ المفتاح الآن.** يبدأ بـ ⁦`gsk_`⁩ ولا يُعرض إلا مرة واحدة. إن ضاع، احذفه وأنشئ مفتاحاً جديداً.
#
# **6.2 احفظ المفتاح بأمان (لا تكتبه في أي خلية)**
#
# المفتاح كلمة مرور تستهلك حصة صاحبها. كل من يرى دفترك يرى كل خلاياه، لذلك **يجب ألا يُكتب المفتاح في أي خلية**.
# 1. من الشريط الأيسر في Colab انقر **أيقونة المفتاح (🔑 Secrets)**.
# 2. اضغط **Add new secret**. الاسم: ⁦`GROQ_API_KEY`⁩. القيمة: الصق مفتاحك.
# 3. فعّل **Notebook access** لهذا السر.
#
# هذا كل شيء. الخلية التالية تقرأ المفتاح من خزنة الأسرار، فلا يحتوي عليه دفترك أبداً: يبقى عملك قابلاً للمشاركة ومفتاحك في أمان.
#
# **لا يوجد مفتاح بعد، أو Groq لا يعمل على شبكتك؟** تستطيع إكمال هذا الجزء.
# حين لا يوجد مفتاح، أو لا تجيب الخدمة، تُرجع الدالة ⁦`ask`⁩ **إجابة نموذجية محفوظة** موسومة بوضوح، فيعمل دورك 8 و9 بالطريقة نفسها.
# أضف المفتاح لاحقاً وأعد تشغيل الخلايا لترى إجابة حية.
#
# </div>
# </details>

# %%
USE_SAVED = False  #@param {type:"boolean"}
MODEL = "llama-3.3-70b-versatile"  #@param {type:"string"}
# USE_SAVED: tick it to use only the saved example answers (no key or internet needed), for example if Groq is down.
# MODEL: which Llama model answers. "llama-3.1-8b-instant" is faster. If Groq retires a model, type a current name
#        from Groq's documentation, then run this cell again.

try:
    from openai import OpenAI
except ImportError:
    get_ipython().run_line_magic("pip", "install -q openai")
    from openai import OpenAI

def connect_llm():
    """Return a client for Groq's free Llama models, or None if no key is set up yet."""
    import os
    if USE_SAVED:
        print("USE_SAVED is ticked: the assistant shows the saved example answers.")
        return None
    key, problem = None, "no secret named GROQ_API_KEY in the 🔑 Secrets panel (step 6.2)"
    try:
        from google.colab import userdata
        key = userdata.get("GROQ_API_KEY")
    except Exception as e:
        if "NotebookAccess" in type(e).__name__:
            problem = "the secret exists but 'Notebook access' is switched off for it (step 6.2, point 3)"
        key = os.environ.get("GROQ_API_KEY")
    if not key:
        print(f"No key yet: {problem}. Fix it, then run this cell again. The rest of the lab works without it.")
        return None
    if not key.startswith("gsk_"):
        print("Warning: Groq keys start with 'gsk_'. Check that you pasted the whole key and nothing else.")
    print("Connected. Your key stayed in the secret store.")
    return OpenAI(base_url="https://api.groq.com/openai/v1", api_key=key)

client = connect_llm()
_SAVED_NOTE = "[Saved example answer: not generated live.]\n"

def ask(question, system="You are a careful engineering assistant. Be brief. Say 'I am not sure' when you are not sure.", saved=None):
    """Send one question to the model and return its answer as text.
    Without a key, or if the service does not answer, return the saved example answer (if there is one), clearly marked."""
    if client is None:
        return (_SAVED_NOTE + saved) if saved else "(no AI answer: see Part 6.1 to add a key)"
    try:
        reply = client.chat.completions.create(
            model=MODEL, temperature=0.2,
            messages=[{"role": "system", "content": system}, {"role": "user", "content": question}])
        return reply.choices[0].message.content
    except Exception as e:   # no internet, a wrong key, a retired MODEL, or the free limit reached
        print(f"The AI service did not answer ({type(e).__name__}: {str(e)[:120]}). Showing the saved example answer instead.")
        return (_SAVED_NOTE + saved) if saved else "(no AI answer this time: try again in a minute)"

def ask_and_review(question, saved, system="You are a careful engineering assistant. Be brief."):
    """For review exercises: everyone reviews the same saved answer; with a key you also see a live one to compare."""
    print("THE ANSWER TO REVIEW (saved, the same for everyone):\n")
    print(saved)
    if client is not None:
        print("\n" + "-" * 70 + "\nA LIVE ANSWER from your key, to compare (it changes every run):\n")
        print(ask(question, system=system))

print(ask("In one sentence, what is a baseline forecast in machine learning?",
          saved="A baseline forecast is the simplest reasonable prediction, such as 'tomorrow equals today', that any real model must beat."))

# %% [markdown]
# **How it works:** `ask` sends your question to Groq's computers, where Llama writes the answer, and returns the text.
# The `system` message sets the assistant's role and rules. `temperature=0.2` makes the answers steadier; higher values make them more varied.
# The same code works with other providers (OpenAI, Anthropic, Google) by changing only `base_url`, the key, and `MODEL`.
#
# The two settings at the top of the cell show as a small form on the right.
# - **`USE_SAVED`:** tick it to work with the saved answers only, for example when the service is down.
# - **`MODEL`:** change it if Groq retires a model.
#
# Run the cell again after changing either.
# If the service fails in the middle of the lab, `ask` prints one line saying so and shows the saved answer instead, so the lab continues without interruption.
# `ask_and_review` serves the exercises where you **review** an AI answer. It prints a saved answer, the same for everyone, and, when your key works, a live answer below it to compare.
#
# ### ✏️ Your turn 8 · Review the table answer
# Review an AI answer about the table's summary statistics, and write what it found, what it missed, and what it invented.
# Below, the question gives the model the summary statistics you read in Part 3 and asks what looks suspicious. Run and compare: set the answer to review against **your** findings table.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **كيف يعمل:** الدالة ⁦`ask`⁩ ترسل سؤالك إلى أجهزة Groq، حيث يكتب Llama الإجابة، ثم تُرجع النص.
# رسالة ⁦`system`⁩ تحدد دور المساعد وقواعده. و⁦`temperature=0.2`⁩ تجعل الإجابات أثبت؛ القيم الأعلى تجعلها أكثر تنوعاً.
# الكود نفسه يعمل مع مزودين آخرين (OpenAI أو Anthropic أو Google) بتغيير ⁦`base_url`⁩ والمفتاح و⁦`MODEL`⁩ فقط.
# الإعدادان في أعلى الخلية يظهران نموذجاً صغيراً على اليمين.
# - **⁦`USE_SAVED`⁩:** فعّله لتعمل بالإجابات المحفوظة فقط، مثلاً حين تتعطل الخدمة.
# - **⁦`MODEL`⁩:** غيّره إن أوقفت Groq نموذجاً.
#
# أعد تشغيل الخلية بعد تغيير أيٍّ منهما.
# وإن تعطلت الخدمة أثناء اللاب، تطبع ⁦`ask`⁩ سطراً واحداً تقول فيه ذلك وتعرض الإجابة المحفوظة بدلاً منها، فيستمر اللاب دون انقطاع.
# أما ⁦`ask_and_review`⁩ فتخدم التمارين التي **تراجع** فيها إجابة ذكاء اصطناعي. تطبع إجابة محفوظة، واحدة للجميع، وحين يعمل مفتاحك تعرض تحتها إجابة حية للمقارنة.
#
# **✏️ دورك 8 · مراجعة إجابة الجدول**
#
# راجع إجابة ذكاء اصطناعي عن الإحصاءات الوصفية للجدول، واكتب ما وجده وما فاته وما اخترعه.
# في الخلية التالية يعطي السؤالُ النموذجَ الإحصاءات الوصفية التي قرأتها في الجزء 3، ويسأله عمّا يبدو مريباً. شغّل وقارن: ضع الإجابة التي تراجعها أمام **جدول ملاحظاتك**.
#
# </div>
# </details>

# %%
# The answer to review: a saved example of the kind of answer an assistant gives, the same for everyone.
# Like real answers, it contains a mistake.
SAVED_TABLE_REVIEW = """- loading_pct minimum of -999.0%: a negative loading is impossible; this looks like a code for a missing reading.
- temp_c maximum of 481.0 °C: far beyond any air temperature on Earth; most likely a logging error.
- loading_pct mean of 7.7%: pulled down by the -999 codes, so this mean is meaningless.
- temp_3h_c maximum of 51.8 °C: very hot, but plausible in a record heat wave.
- tie_closed mean of 1.0: the tie switch was never opened, so this transformer never had to carry the whole load alone."""

summary = df.describe(include="number").round(1).to_string()
ask_and_review(f"""These are summary statistics of an hourly table from the load logger of a distribution transformer.
Loading is in % of the transformer's rating; above 100% it is overloaded. Temperatures are air temperatures in °C.
tie_closed is 1 when the tie switch to the neighbouring feeder is closed and 0 when it is open.
List the values that look physically suspicious and say why, in at most five bullet points.

{summary}""", saved=SAVED_TABLE_REVIEW)

# %% [markdown]
# Now judge the assistant like an engineer. ✏️ Fill in the three answers in the next cell, in your own words.
# - **Found:** did it find the −999 readings and the 481 °C?
# - **Missed:** did it miss anything you found (the zero dropouts, the November 2022 gap, the leaking `overload_report_time`)? It cannot see those in a summary. That is a lesson in itself: it only knows what you give it.
# - **Invented:** did it state a number or a claim that is not in the table?
#
# One of the five claims in the answer to review is contradicted by something you already counted in Part 3. Find it. If you also see a live answer, judge it the same way.
# <details><summary>💡 Hint</summary>
#
# Take the lines one at a time. For each, find the cell in Part 3 that confirms or refutes it, and compare. Be most careful with rounded averages: what can a rounded mean hide?
# </details>
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# الآن احكم على المساعد كمهندس. ✏️ املأ الإجابات الثلاث في الخلية التالية بكلماتك:
# - **ما وجده:** هل وجد قراءات −999 والـ 481 °م؟
# - **ما فاته:** هل فاته شيء وجدته أنت (انقطاعات الصفر، فجوة نوفمبر 2022، عمود ⁦`overload_report_time`⁩ المسرِّب)؟ لا يستطيع رؤية هذه في ملخص إحصائي. وهذا درس بحد ذاته: هو لا يعرف إلا ما تعطيه.
# - **ما اخترعه:** هل ذكر رقماً أو ادعاءً غير موجود في الجدول؟
#
# واحد من الادعاءات الخمسة في الإجابة التي تراجعها يناقضه شيء عددته بنفسك في الجزء 3. أوجده. وإن ظهرت لك إجابة حية أيضاً، فاحكم عليها بالطريقة نفسها.
# <details><summary>💡 تلميح</summary>
#
# خذ الأسطر واحداً واحداً. لكل سطر، جِد الخلية في الجزء 3 التي تؤكده أو تنقضه، وقارن. وكن أشد حذراً مع المتوسطات المقرّبة: ماذا يمكن أن يُخفي متوسط مقرَّب؟
# </details>
#
# </div>
# </details>

# %%
ai_found   = ""   # ✏️ what the assistant found that you had also found
ai_missed  = ""   # ✏️ what it missed, and why it could not have seen it
ai_invented = ""  # ✏️ anything it stated that the table does not support ("nothing" is a valid answer)

# %% [markdown]
# ### ✏️ Your turn 9 · Verify its code
# Run the assistant's code for counting the −999 readings, and check it against your own checked count.
# Ask the assistant to write the pandas line that counts rows with loading −999. Run **its** code in the cell after.
# Then compare the result with the number the "checker" accepted in Your turn 3. If the numbers differ, the code is wrong, however confident the explanation sounded.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **✏️ دورك 9 · التحقق من كوده**
#
# شغّل كود المساعد لعدّ قراءات −999، وقارنه بعددك الذي تحققت منه.
# اطلب من المساعد أن يكتب سطر pandas الذي يعدّ الصفوف التي تحميلها −999. شغّل **كوده** في الخلية التي بعدها.
# ثم قارن النتيجة بالرقم الذي قبله «المدقق» في دورك 3. إن اختلف الرقمان فالكود خطأ، مهما بدا شرحه واثقاً.
#
# </div>
# </details>

# %%
print(ask("A pandas DataFrame named df has a column loading_pct. Write one line of Python that counts the rows where loading_pct equals -999. Reply with the code only.",
          saved='df[df["loading_pct"] == -999].shape[0]'))

# %%
ai_count = None   # ✏️ paste the assistant's line here (without print), e.g.  ai_count = ...
print("assistant's code gives:", ai_count, "   your checked answer:", n_missing_code)

# %% [markdown]
# > **The habit for the whole course:** use the assistant to go faster, never to skip the check. Code is checked by running it on a case whose answer you know. Numbers are checked against the data. Claims are checked against a source.
# > That way you work quickly and safely.
#
# ---
# # Part 7 · Hand in the lab
#
# Sign and hand in. All you need to do is three steps:
# 1. Type your **university email** in the next cell. It signs your hand-in: the signature is computed from your email and your checked answers, so a block copied from someone else does not match.
# 2. Share your notebook with your instructor: **Share → type your instructor's email → Viewer → Send**, then **Copy link**, and paste the link into `NOTEBOOK_LINK`. Do not choose *Anyone with the link*: it shows your email to anyone who gets the link. Your notebook, with its outputs, is the real evidence of your work.
# 3. 🟢 Run the cell and hand in the whole output, the way your instructor asks.
#
# A line that says *missing* points to an unfinished part: go back to that part, then run the cell again.
#
# Before you close the notebook: which step took you longest, and what finally made it work? Share that with your classmates. It saves the next person time.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# > **العادة التي نريدها طوال المقرر:** استخدم المساعد لتسرع، لا لتتخطى التحقق. الكود يُتحقق منه بتشغيله على حالة تعرف إجابتها. الأرقام يُتحقق منها على البيانات. والادعاءات يُتحقق منها من مصدر.
# > بهذا تعمل بسرعة وأمان.
#
# **الجزء 7 · تسليم اللاب**
#
# وقّع وسلّم. كل ما عليك هو ثلاث خطوات:
# 1. اكتب **بريدك الجامعي** في الخلية التالية. هو توقيع تسليمك: التوقيع يُحسب من بريدك ومن إجاباتك المتحقَّق منها، فالكتلة المنسوخة من زميل لا تطابق.
# 2. شارك دفترك مع أستاذك: **Share ثم اكتب بريد أستاذك ثم Viewer ثم Send**، ثم **Copy link**، والصق الرابط في ⁦`NOTEBOOK_LINK`⁩. لا تختر *Anyone with the link*، فهو يُظهر بريدك لكل من يصله الرابط. دفترك بمخرجاته هو الدليل الحقيقي على عملك.
# 3. 🟢 شغّل الخلية وسلّم المخرجات كاملة بالطريقة التي يطلبها أستاذك.
#
# السطر الذي فيه كلمة *missing* يدل على جزء لم يكتمل: ارجع إلى ذلك الجزء، ثم أعد تشغيل الخلية.
#
# قبل أن تغلق الدفتر: أي خطوة أخذت منك أطول وقت، وما الذي جعلها تنجح في النهاية؟ شاركها مع زملائك، فهي توفّر الوقت على من يواجهها بعدك.
#
# </div>
# </details>

# %%
STUDENT_EMAIL = ""   # ✏️ your university email
NOTEBOOK_LINK = ""   # ✏️ Share → your instructor's email → Viewer → Send, then Copy link

print("EE 3040 · Lab 1 hand-in")
print("=" * 60)
try:
    print("Email:", _show(STUDENT_EMAIL.strip().lower()))
    print("Notebook:", _show(NOTEBOOK_LINK))
except NameError:
    STUDENT_EMAIL, NOTEBOOK_LINK = "", ""
    print("Email: missing: run the email cell above first")
try:
    print("Checks passed:", len(_progress), "of", len(_ANSWERS))
except Exception as _e:
    print('missing: run that part first (' + type(_e).__name__ + ')')
try:
    print("Progress:", json.dumps(_progress, sort_keys=True))
except Exception as _e:
    print('missing: run that part first (' + type(_e).__name__ + ')')
try:
    print(f"Baseline MAE (course data, all hours): {_show(_progress.get('baseline_mae'))} % of rating")
except Exception as _e:
    print('missing: run that part first (' + type(_e).__name__ + ')')
try:
    print("\nFindings on the course data:"); print(pd.DataFrame(findings).to_string(index=False))
except Exception as _e:
    print('missing: run that part first (' + type(_e).__name__ + ')')
try:
    print("\nAI assistant:  found:", _show(ai_found), "|  missed:", _show(ai_missed), "|  invented:", _show(ai_invented))
except Exception as _e:
    print('missing: run that part first (' + type(_e).__name__ + ')')
print("\nSignature:", _signature(STUDENT_EMAIL.strip().lower(), _progress) if STUDENT_EMAIL.strip() else "missing: type your email")

# %% [markdown]
# ---
# # Part 8 · Homework: your own data (due one week after the lab)
#
# Everything above was practice on the course table. Now repeat the first look on the data you found for your challenge.
# Give it the time it deserves. Understanding your own data is the heart of the project, and every later lab builds on what you find here.
#
# **How to load it**
# - **A file on your laptop:** run the next cell with `MY_FILE = "upload"`; a button appears to choose the file.
# - **A public link to a CSV:** paste it as `MY_FILE = "https://..."`.
# - **Excel:** replace `pd.read_csv` with `pd.read_excel`.
# - **Track B (images):** load your **label file** (one row per image with its class), not the images. Images come in Lab 7.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **الجزء 8 · الواجب: بياناتك (يُسلَّم بعد أسبوع من اللاب)**
#
# كل ما سبق تدريب على جدول المقرر. الآن كرر النظرة الأولى على البيانات التي وجدتها لتحديك.
# أعطها الوقت الذي تستحقه. فهم بياناتك هو قلب المشروع، وكل لاب قادم يُبنى على ما تكتشفه هنا.
#
# **كيف تحمّلها**
#
# - **ملف على جهازك:** شغّل الخلية التالية مع ⁦`MY_FILE = "upload"`⁩، فيظهر زر لاختيار الملف.
# - **رابط عام لملف CSV:** الصقه هكذا ⁦`MY_FILE = "https://..."`⁩.
# - **ملف Excel:** استبدل ⁦`pd.read_csv`⁩ بـ ⁦`pd.read_excel`⁩.
# - **المسار B (الصور):** حمّل **ملف التسميات** (صف لكل صورة مع فئتها)، لا الصور نفسها. الصور في اللاب 7.
#
# </div>
# </details>

# %%
MY_FILE   = ""          # ✏️ "upload", or a link to a CSV
SOURCE    = ""          # ✏️ where the data comes from: organisation, link, licence

my_data = None
if MY_FILE == "upload":
    from google.colab import files
    uploaded = files.upload()
    name = next(iter(uploaded))
    my_data = pd.read_excel(name) if name.endswith(("xls", "xlsx")) else pd.read_csv(name)
elif MY_FILE:
    my_data = pd.read_csv(MY_FILE)
else:
    print("Set MY_FILE above to load your data.")

if my_data is not None:
    print(my_data.shape)
    display(my_data.head())
    display(my_data.describe(include="all").T.head(20))
    print("empty cells per column:"); print(my_data.isna().sum().sort_values(ascending=False).head(10))

# %% [markdown]
# ✏️ Use the same five commands and the same questions as Part 3 on your own table:
# - Which column is the **answer** you want to predict? Is it there for every row?
# - Which values are physically impossible or suspicious? How is "missing" written?
# - Is there a time column? Are there gaps? Did anything change part-way (a new sensor, a new form, a new unit)?
# - Is there any column that is written **after** the event you want to predict?
#
# Plot the answer column over time (or its counts per class), then write your three most important findings below.
# The next cell is a starter: each step is a comment, and each `# ✏️` line is an example to adapt.
# Remove the `#` at the start of a line to run it, and change the column names to yours. Add as many cells as you need.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# ✏️ استخدم الأوامر الخمسة نفسها والأسئلة نفسها من الجزء 3 على جدولك:
# - أي عمود هو **الإجابة** التي تريد التنبؤ بها؟ وهل هو موجود لكل صف؟
# - أي القيم مستحيلة فيزيائياً أو مريبة؟ وكيف تُكتب القيمة المفقودة؟
# - هل يوجد عمود زمن؟ هل فيه فجوات؟ هل تغيّر شيء في المنتصف (حساس جديد، نموذج جديد، وحدة جديدة)؟
# - هل يوجد عمود يُكتب **بعد** الحدث الذي تريد التنبؤ به؟
#
# ارسم عمود الإجابة عبر الزمن (أو عدد كل فئة)، ثم اكتب أهم ثلاث ملاحظات لديك في الأسفل.
# الخلية التالية نقطة انطلاق: كل خطوة تعليق، وكل سطر ⁦`# ✏️`⁩ مثال تعدّله.
# احذف ⁦`#`⁩ من بداية السطر لتشغّله، وغيّر أسماء الأعمدة إلى أسماء أعمدتك. وأضف من الخلايا ما تحتاج.
#
# </div>
# </details>

# %%
# 1. The five commands of every first look (shape and head were shown above)
# ✏️ my_data.dtypes
# ✏️ my_data.describe(include="number").round(1)
# ✏️ my_data.isna().sum()

# 2. How is "missing" written? Count a suspicious value in one column (-999, 0, 9999, "n/a", ...)
# ✏️ (my_data["your_column"] == -999).sum()

# 3. If there is a time column: turn it into dates, then find the largest gap
# ✏️ times = pd.to_datetime(my_data["your_time_column"])
# ✏️ times.diff().max()

# 4. Plot the answer column over time, or count each class if it is a category
# ✏️ my_data.plot(x="your_time_column", y="your_answer_column", figsize=(12, 3))
# ✏️ my_data["your_answer_column"].value_counts().plot(kind="bar")

# 5. Leakage: list the columns, and ask of each "will I have this value at the moment of prediction?"
# ✏️ list(my_data.columns)

# %%
my_findings = [
    # ✏️ your three most important findings: text between the quotes, a number after "rows"
    {"what I found": "", "rows": None, "what it means": "", "what I will do": ""},
    {"what I found": "", "rows": None, "what it means": "", "what I will do": ""},
    {"what I found": "", "rows": None, "what it means": "", "what I will do": ""},
]
pd.DataFrame(my_findings)

# %% [markdown]
# ### Hand in the homework
# Write and hand in. All you need to do is write your three findings, then 🟢 run the cell below and hand in its output, the way your instructor asks.
# Use the same notebook link as the lab; it now shows your homework too.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **تسليم الواجب**
#
# اكتب وسلّم. كل ما عليك هو أن تكتب ملاحظاتك الثلاث، ثم 🟢 تشغّل الخلية التالية وتسلّم مخرجاتها بالطريقة التي يطلبها أستاذك.
# استخدم رابط الدفتر نفسه الذي سلّمت به اللاب؛ فهو يُظهر الواجب الآن أيضاً.
#
# </div>
# </details>

# %%
print("EE 3040 · Lab 1 homework")
print("=" * 60)
try:
    print("Email:", _show(STUDENT_EMAIL.strip().lower()))
    print("Notebook:", _show(NOTEBOOK_LINK))
except NameError:
    STUDENT_EMAIL, NOTEBOOK_LINK = "", ""
    print("Email: missing: run the email cell above first")
try:
    print("My data source:", _show(SOURCE))
except Exception as _e:
    print('missing: run that part first (' + type(_e).__name__ + ')')
try:
    print("Rows x columns loaded:", my_data.shape if my_data is not None else "missing")
except Exception as _e:
    print('missing: run that part first (' + type(_e).__name__ + ')')
try:
    print(pd.DataFrame(my_findings).to_string(index=False) if any(f.get("what I found") for f in my_findings) else "My findings: missing")
except Exception as _e:
    print('missing: run that part first (' + type(_e).__name__ + ')')
print("\nSignature:", _signature(STUDENT_EMAIL.strip().lower(), SOURCE, my_findings) if STUDENT_EMAIL.strip() else "missing: type your email")

# %% [markdown]
# ---
# ## What you learned
# - A notebook runs top to bottom; restart and run all when in doubt.
# - Five commands start every first look: `shape`, `head`, `dtypes`, `describe`, `isna`. Then count with a condition and **plot**.
# - Missing data often hides as a number (−999, 0). Impossible values, gaps, logger or CT changes, and leaking columns are normal on day one, and each needs a written decision. Some unusual values, like the tie switch being open, are real and must be kept.
# - A baseline is the simplest reasonable forecast. Report its error on all hours **and** on the hours that matter, clearly and honestly.
# - An AI assistant speeds you up and can be wrong with confidence. Check its code by running it and its claims against the data, so you work quickly and safely.
#
# **Next: Lab 2 · From a messy table to a clean one.** You turn every row of your findings table into a line of code, and build the cleaning pipeline your model uses for the rest of the semester.
#
# <details><summary>🌐 الترجمة العربية</summary>
# <div dir="rtl" align="right">
#
# **ما تعلمته**
#
# - الدفتر يعمل من الأعلى إلى الأسفل؛ وعند الشك أعد التشغيل من البداية.
# - خمسة أوامر تبدأ بها كل نظرة أولى: ⁦`shape`⁩ و⁦`head`⁩ و⁦`dtypes`⁩ و⁦`describe`⁩ و⁦`isna`⁩. ثم العدّ بشرط، ثم **الرسم**.
# - القيمة المفقودة كثيراً ما تختبئ في رقم (−999 أو 0). والقيم المستحيلة والفجوات وتغيير المسجّل أو محوّل التيار والأعمدة المسرِّبة أمور طبيعية في اليوم الأول، وكل واحدة تحتاج قراراً مكتوباً. وبعض القيم غير المعتادة، مثل فتح مفتاح الربط، حقيقية ويجب الاحتفاظ بها.
# - خط الأساس أبسط توقع معقول. اعرض خطأه على كل الساعات **و**على الساعات التي تهم، بدقة ووضوح.
# - المساعد الذكي يسرّعك وقد يخطئ بثقة. تحقق من كوده بتشغيله، ومن ادعاءاته على البيانات، فتعمل بسرعة وأمان.
#
# **التالي: اللاب 2 · من جدول فوضوي إلى جدول نظيف.** تحوّل كل صف في جدول ملاحظاتك إلى سطر كود، وتبني pipeline التنظيف الذي يستخدمه نموذجك بقية الفصل.
#
# </div>
# </details>
